# %% [markdown]
# ### Wordnet Synsets for OES categories using O-net grouping

# %%
import numpy as np 
import pandas as pd
from nltk.corpus import wordnet

# %%
occu = pd.read_table("Occupations.tsv")
clusters = pd.read_table("CareerClusters.tsv")

# %%
occu.head()
# Out:
#          Code                                        Occupation  \
# 0  17-3021.00  Aerospace Engineering and Operations Technicians
# 1  17-2011.00                               Aerospace Engineers
# 2  17-2021.00                            Agricultural Engineers
# 3  17-1011.00          Architects, Except Landscape and Naval
# 4  17-3011.00                  Architectural and Civil Drafters
#
#                      Job Family
# 0  Architecture and Engineering
# 1  Architecture and Engineering
# 2  Architecture and Engineering
# 3  Architecture and Engineering
# 4  Architecture and Engineering

# %%
clusters.head()
# Out:
#                           Career Cluster        Career Pathway        Code  \
# 0  Agriculture, Food & Natural Resources  Agribusiness Systems  11-9013.03
# 1  Agriculture, Food & Natural Resources  Agribusiness Systems  13-1021.00
# 2  Agriculture, Food & Natural Resources  Agribusiness Systems  11-9013.02
# 3  Agriculture, Food & Natural Resources  Agribusiness Systems  13-1074.00
# 4  Agriculture, Food & Natural Resources  Agribusiness Systems  11-9013.00
#
#                                           Occupation
# 0                              Aquacultural Managers
# 1        Buyers and Purchasing Agents, Farm Products
# 2                            Farm and Ranch Managers
# 3                             Farm Labor Contractors
# 4  Farmers, Ranchers, and Other Agricultural Mana...

# %%
onetM = pd.merge(occu, clusters, on=["Code"])

# %%
onetM['fullCode'] = onetM.Code
onetM['SCode'] = onetM.Code.apply(lambda x: x[7:])
onetM['Code'] = onetM.Code.apply(lambda x: x[:7])
onetM.head(42)

# %%
onetM['word_tokens'] = onetM.Occupation_y.apply(tokenizer.tokenize)

# %%
oes = pd.read_table("oesCat.tsv")
oes.head()
# Out:
#       Code                            Title
# 0  11-0000           Management Occupations
# 1  11-1000                   Top Executives
# 2  11-1010                 Chief Executives
# 3  11-1011                 Chief Executives
# 4  11-1020  General and Operations Managers

# %%
onet = pd.merge(onetM, oes, on="Code")

# %%
onet.head()

# %% [markdown]
# ## Pull Summary Reports for roles from O*net.org

# %%
baseurl = "https://www.onetonline.org/link/summary/"
#from urllib.request import Request, urlopen, urlretrieve
#from urllib.error import HTTPError
#from urllib.error import HTTPError
#from urllib.error import HTTPError
from bs4 import BeautifulSoup
from downloader import Downloader

# %%
D = Downloader()

# %%
def getPages(col):
    pages = []
    for i in col:
        html = D(baseurl+i)
        pages.append(html['html'])
    return pages

# %%
onetReports = getPages(onet.fullCode)
# Out:
# Downloading:  https://www.onetonline.org/link/summary/17-3021.00
# Downloading:  https://www.onetonline.org/link/summary/17-2011.00
# Downloading:  https://www.onetonline.org/link/summary/17-2021.00
# Downloading:  https://www.onetonline.org/link/summary/17-1011.00
# Downloading:  https://www.onetonline.org/link/summary/17-3011.00
# Downloading:  https://www.onetonline.org/link/summary/17-3011.01
# Downloading:  https://www.onetonline.org/link/summary/17-3011.02
# Downloading:  https://www.onetonline.org/link/summary/17-3027.01
# Downloading:  https://www.onetonline.org/link/summary/17-3027.00
# Downloading:  https://www.onetonline.org/link/summary/17-2141.02
# Downloading:  https://www.onetonline.org/link/summary/17-2141.01
# Downloading:  https://www.onetonline.org/link/summary/17-2141.00
# Downloading:  https://www.onetonline.org/link/summary/17-2199.01
# Downloading:  https://www.onetonline.org/link/summary/17-2199.03
# Downloading:  https://www.onetonline.org/link/summary/17-2199.00
# Downloading:  https://www.onetonline.org/link/summary/17-2199.04
# Downloading:  https://www.onetonline.org/link/summary/17-2199.05
# Downloading:  https://www.onetonline.org/link/summary/17-2199.06
# Downloading:  https://www.onetonline.org/link/summary/17-2199.09
# Downloading:  https://www.onetonline.org/link/summary/17-2199.07
# Downloading:  https://www.onetonline.org/link/summary/17-2199.08
# Downloading:  https://www.onetonline.org/link/summary/17-2199.11
# Downloading:  https://www.onetonline.org/link/summary/17-2199.02
# Downloading:  https://www.onetonline.org/link/summary/17-2199.10
# Downloading:  https://www.onetonline.org/link/summary/17-2031.00
# Downloading:  https://www.onetonline.org/link/summary/17-1021.00
# Downloading:  https://www.onetonline.org/link/summary/17-2041.00
# Downloading:  https://www.onetonline.org/link/summary/17-3022.00
# Downloading:  https://www.onetonline.org/link/summary/17-2051.00
# Downloading:  https://www.onetonline.org/link/summary/17-2051.01
# Downloading:  https://www.onetonline.org/link/summary/17-2061.00
# Downloading:  https://www.onetonline.org/link/summary/17-3019.00
# Downloading:  https://www.onetonline.org/link/summary/17-3023.00
# Downloading:  https://www.onetonline.org/link/summary/17-3023.03
# Downloading:  https://www.onetonline.org/link/summary/17-3023.01
# Downloading:  https://www.onetonline.org/link/summary/17-3012.00
# Downloading:  https://www.onetonline.org/link/summary/17-3012.02
# Downloading:  https://www.onetonline.org/link/summary/17-3012.01
# Downloading:  https://www.onetonline.org/link/summary/17-3029.02
# Downloading:  https://www.onetonline.org/link/summary/17-3029.03
# Downloading:  https://www.onetonline.org/link/summary/17-3029.04
# Downloading:  https://www.onetonline.org/link/summary/17-3029.00
# Downloading:  https://www.onetonline.org/link/summary/17-3029.10
# Downloading:  https://www.onetonline.org/link/summary/17-3029.05
# Downloading:  https://www.onetonline.org/link/summary/17-3029.06
# Downloading:  https://www.onetonline.org/link/summary/17-3029.09
# Downloading:  https://www.onetonline.org/link/summary/17-3029.07
# Downloading:  https://www.onetonline.org/link/summary/17-3029.12
# Downloading:  https://www.onetonline.org/link/summary/17-3029.11
# Downloading:  https://www.onetonline.org/link/summary/17-3029.01
# Downloading:  https://www.onetonline.org/link/summary/17-3029.08
# Downloading:  https://www.onetonline.org/link/summary/17-2071.00
# Downloading:  https://www.onetonline.org/link/summary/17-3024.00
# Downloading:  https://www.onetonline.org/link/summary/17-3024.01
# Downloading:  https://www.onetonline.org/link/summary/17-2072.00
# Downloading:  https://www.onetonline.org/link/summary/17-2072.01
# Downloading:  https://www.onetonline.org/link/summary/17-3025.00
# Downloading:  https://www.onetonline.org/link/summary/17-2081.00
# Downloading:  https://www.onetonline.org/link/summary/17-2081.01
# Downloading:  https://www.onetonline.org/link/summary/17-2111.02
# Downloading:  https://www.onetonline.org/link/summary/17-2111.00
# Downloading:  https://www.onetonline.org/link/summary/17-2111.01
# Downloading:  https://www.onetonline.org/link/summary/17-2111.03
# Downloading:  https://www.onetonline.org/link/summary/17-1022.01
# Downloading:  https://www.onetonline.org/link/summary/17-1022.00
# Downloading:  https://www.onetonline.org/link/summary/17-2112.01
# Downloading:  https://www.onetonline.org/link/summary/17-2112.00
# Downloading:  https://www.onetonline.org/link/summary/17-3026.00
# Downloading:  https://www.onetonline.org/link/summary/17-1012.00
# Downloading:  https://www.onetonline.org/link/summary/17-3031.02
# Downloading:  https://www.onetonline.org/link/summary/17-3031.00
# Downloading:  https://www.onetonline.org/link/summary/17-3031.01
# Downloading:  https://www.onetonline.org/link/summary/17-2121.02
# Downloading:  https://www.onetonline.org/link/summary/17-2121.01
# Downloading:  https://www.onetonline.org/link/summary/17-2121.00
# Downloading:  https://www.onetonline.org/link/summary/17-2131.00
# Downloading:  https://www.onetonline.org/link/summary/17-3013.00
# Downloading:  https://www.onetonline.org/link/summary/17-2151.00
# Downloading:  https://www.onetonline.org/link/summary/17-2161.00
# Downloading:  https://www.onetonline.org/link/summary/17-2171.00
# Downloading:  https://www.onetonline.org/link/summary/27-2011.00
# Downloading:  https://www.onetonline.org/link/summary/27-1011.00
# Downloading:  https://www.onetonline.org/link/summary/27-1019.00
# Downloading:  https://www.onetonline.org/link/summary/27-2021.00
# Downloading:  https://www.onetonline.org/link/summary/27-4011.00
# Downloading:  https://www.onetonline.org/link/summary/27-3021.00
# Downloading:  https://www.onetonline.org/link/summary/27-4012.00
# Downloading:  https://www.onetonline.org/link/summary/27-4031.00
# Downloading:  https://www.onetonline.org/link/summary/27-2032.00
# Downloading:  https://www.onetonline.org/link/summary/27-2022.00
# Downloading:  https://www.onetonline.org/link/summary/27-1021.00
# Downloading:  https://www.onetonline.org/link/summary/27-3043.04
# Downloading:  https://www.onetonline.org/link/summary/27-3043.05
# Downloading:  https://www.onetonline.org/link/summary/27-3043.00
# Downloading:  https://www.onetonline.org/link/summary/27-1012.00
# Downloading:  https://www.onetonline.org/link/summary/27-2031.00
# Downloading:  https://www.onetonline.org/link/summary/27-1029.00
# Downloading:  https://www.onetonline.org/link/summary/27-2012.02
# Downloading:  https://www.onetonline.org/link/summary/27-2012.01
# Downloading:  https://www.onetonline.org/link/summary/27-2012.00
# Downloading:  https://www.onetonline.org/link/summary/27-2012.03
# Downloading:  https://www.onetonline.org/link/summary/27-2012.04
# Downloading:  https://www.onetonline.org/link/summary/27-2012.05
# Downloading:  https://www.onetonline.org/link/summary/27-3041.00
# Downloading:  https://www.onetonline.org/link/summary/27-2099.00
# Downloading:  https://www.onetonline.org/link/summary/27-1022.00
# Downloading:  https://www.onetonline.org/link/summary/27-4032.00
# Downloading:  https://www.onetonline.org/link/summary/27-1013.00
# Downloading:  https://www.onetonline.org/link/summary/27-1023.00
# Downloading:  https://www.onetonline.org/link/summary/27-1024.00
# Downloading:  https://www.onetonline.org/link/summary/27-1025.00
# Downloading:  https://www.onetonline.org/link/summary/27-3091.00
# Downloading:  https://www.onetonline.org/link/summary/27-4099.00
# Downloading:  https://www.onetonline.org/link/summary/27-3099.00
# Downloading:  https://www.onetonline.org/link/summary/27-1026.00
# Downloading:  https://www.onetonline.org/link/summary/27-1014.00
# Downloading:  https://www.onetonline.org/link/summary/27-2041.04
# Downloading:  https://www.onetonline.org/link/summary/27-2041.01
# Downloading:  https://www.onetonline.org/link/summary/27-2041.00
# Downloading:  https://www.onetonline.org/link/summary/27-2042.00
# Downloading:  https://www.onetonline.org/link/summary/27-2042.02
# Downloading:  https://www.onetonline.org/link/summary/27-2042.01
# Downloading:  https://www.onetonline.org/link/summary/27-4021.00
# Downloading:  https://www.onetonline.org/link/summary/27-3012.00
# Downloading:  https://www.onetonline.org/link/summary/27-3031.00
# Downloading:  https://www.onetonline.org/link/summary/27-3011.00
# Downloading:  https://www.onetonline.org/link/summary/27-4013.00
# Downloading:  https://www.onetonline.org/link/summary/27-3022.00
# Downloading:  https://www.onetonline.org/link/summary/27-1027.00
# Downloading:  https://www.onetonline.org/link/summary/27-4014.00
# Downloading:  https://www.onetonline.org/link/summary/27-3042.00
# Downloading:  https://www.onetonline.org/link/summary/27-2023.00
# Downloading:  https://www.onetonline.org/link/summary/37-2019.00
# Downloading:  https://www.onetonline.org/link/summary/37-1011.00
# Downloading:  https://www.onetonline.org/link/summary/37-1012.00
# Downloading:  https://www.onetonline.org/link/summary/37-3019.00
# Downloading:  https://www.onetonline.org/link/summary/37-2011.00
# Downloading:  https://www.onetonline.org/link/summary/37-3011.00
# Downloading:  https://www.onetonline.org/link/summary/37-2012.00
# Downloading:  https://www.onetonline.org/link/summary/37-2021.00
# Downloading:  https://www.onetonline.org/link/summary/37-3012.00
# Downloading:  https://www.onetonline.org/link/summary/37-3013.00
# Downloading:  https://www.onetonline.org/link/summary/13-2011.01
# Downloading:  https://www.onetonline.org/link/summary/13-2011.00
# Downloading:  https://www.onetonline.org/link/summary/13-2011.02
# Downloading:  https://www.onetonline.org/link/summary/13-1011.00
# Downloading:  https://www.onetonline.org/link/summary/13-2021.00
# Downloading:  https://www.onetonline.org/link/summary/13-2021.02
# Downloading:  https://www.onetonline.org/link/summary/13-2021.01
# Downloading:  https://www.onetonline.org/link/summary/13-2031.00
# Downloading:  https://www.onetonline.org/link/summary/13-1199.04
# Downloading:  https://www.onetonline.org/link/summary/13-1199.00
# Downloading:  https://www.onetonline.org/link/summary/13-1199.03
# Downloading:  https://www.onetonline.org/link/summary/13-1199.01
# Downloading:  https://www.onetonline.org/link/summary/13-1199.06
# Downloading:  https://www.onetonline.org/link/summary/13-1199.02
# Downloading:  https://www.onetonline.org/link/summary/13-1199.05
# Downloading:  https://www.onetonline.org/link/summary/13-1021.00
# Downloading:  https://www.onetonline.org/link/summary/13-1031.00
# Downloading:  https://www.onetonline.org/link/summary/13-1031.01
# Downloading:  https://www.onetonline.org/link/summary/13-1031.02
# Downloading:  https://www.onetonline.org/link/summary/13-1141.00
# Downloading:  https://www.onetonline.org/link/summary/13-1041.00
# Downloading:  https://www.onetonline.org/link/summary/13-1041.06
# Downloading:  https://www.onetonline.org/link/summary/13-1041.01
# Downloading:  https://www.onetonline.org/link/summary/13-1041.03
# Downloading:  https://www.onetonline.org/link/summary/13-1041.04
# Downloading:  https://www.onetonline.org/link/summary/13-1041.02
# Downloading:  https://www.onetonline.org/link/summary/13-1041.07
# Downloading:  https://www.onetonline.org/link/summary/13-1051.00
# Downloading:  https://www.onetonline.org/link/summary/13-2041.00
# Downloading:  https://www.onetonline.org/link/summary/13-2071.00
# Downloading:  https://www.onetonline.org/link/summary/13-2071.01
# Downloading:  https://www.onetonline.org/link/summary/13-1074.00
# Downloading:  https://www.onetonline.org/link/summary/13-2051.00
# Downloading:  https://www.onetonline.org/link/summary/13-2061.00
# Downloading:  https://www.onetonline.org/link/summary/13-2099.01
# Downloading:  https://www.onetonline.org/link/summary/13-2099.00
# Downloading:  https://www.onetonline.org/link/summary/13-2099.04
# Downloading:  https://www.onetonline.org/link/summary/13-2099.03
# Downloading:  https://www.onetonline.org/link/summary/13-2099.02
# Downloading:  https://www.onetonline.org/link/summary/13-1131.00
# Downloading:  https://www.onetonline.org/link/summary/13-1071.00
# Downloading:  https://www.onetonline.org/link/summary/13-1032.00
# Downloading:  https://www.onetonline.org/link/summary/13-2053.00
# Downloading:  https://www.onetonline.org/link/summary/13-1075.00
# Downloading:  https://www.onetonline.org/link/summary/13-2072.00
# Downloading:  https://www.onetonline.org/link/summary/13-1081.00
# Downloading:  https://www.onetonline.org/link/summary/13-1081.02
# Downloading:  https://www.onetonline.org/link/summary/13-1081.01
# Downloading:  https://www.onetonline.org/link/summary/13-1111.00
# Downloading:  https://www.onetonline.org/link/summary/13-1161.00
# Downloading:  https://www.onetonline.org/link/summary/13-1121.00
# Downloading:  https://www.onetonline.org/link/summary/13-2052.00
# Downloading:  https://www.onetonline.org/link/summary/13-1023.00
# Downloading:  https://www.onetonline.org/link/summary/13-2081.00
# Downloading:  https://www.onetonline.org/link/summary/13-2082.00
# Downloading:  https://www.onetonline.org/link/summary/13-1151.00
# Downloading:  https://www.onetonline.org/link/summary/13-1022.00
# Downloading:  https://www.onetonline.org/link/summary/21-1021.00
# Downloading:  https://www.onetonline.org/link/summary/21-2011.00
# Downloading:  https://www.onetonline.org/link/summary/21-1099.00
# Downloading:  https://www.onetonline.org/link/summary/21-1094.00
# Downloading:  https://www.onetonline.org/link/summary/21-1019.00
# Downloading:  https://www.onetonline.org/link/summary/21-2021.00
# Downloading:  https://www.onetonline.org/link/summary/21-1012.00
# Downloading:  https://www.onetonline.org/link/summary/21-1091.00
# Downloading:  https://www.onetonline.org/link/summary/21-1022.00
# Downloading:  https://www.onetonline.org/link/summary/21-1013.00
# Downloading:  https://www.onetonline.org/link/summary/21-1023.00
# Downloading:  https://www.onetonline.org/link/summary/21-1014.00
# Downloading:  https://www.onetonline.org/link/summary/21-1092.00
# Downloading:  https://www.onetonline.org/link/summary/21-1015.00
# Downloading:  https://www.onetonline.org/link/summary/21-2099.00
# Downloading:  https://www.onetonline.org/link/summary/21-1093.00
# Downloading:  https://www.onetonline.org/link/summary/21-1029.00
# Downloading:  https://www.onetonline.org/link/summary/21-1011.00
# Downloading:  https://www.onetonline.org/link/summary/15-2011.00
# Downloading:  https://www.onetonline.org/link/summary/15-2041.01
# Downloading:  https://www.onetonline.org/link/summary/15-2041.02
# Downloading:  https://www.onetonline.org/link/summary/15-2041.00
# Downloading:  https://www.onetonline.org/link/summary/15-1199.08
# Downloading:  https://www.onetonline.org/link/summary/15-1199.00
# Downloading:  https://www.onetonline.org/link/summary/15-1199.02
# Downloading:  https://www.onetonline.org/link/summary/15-1199.07
# Downloading:  https://www.onetonline.org/link/summary/15-1199.06
# Downloading:  https://www.onetonline.org/link/summary/15-1199.12
# Downloading:  https://www.onetonline.org/link/summary/15-1199.05
# Downloading:  https://www.onetonline.org/link/summary/15-1199.04
# Downloading:  https://www.onetonline.org/link/summary/15-1199.09
# Downloading:  https://www.onetonline.org/link/summary/15-1199.10
# Downloading:  https://www.onetonline.org/link/summary/15-1199.01
# Downloading:  https://www.onetonline.org/link/summary/15-1199.11
# Downloading:  https://www.onetonline.org/link/summary/15-1199.03
# Downloading:  https://www.onetonline.org/link/summary/15-1111.00
# Downloading:  https://www.onetonline.org/link/summary/15-1143.00
# Downloading:  https://www.onetonline.org/link/summary/15-1143.01
# Downloading:  https://www.onetonline.org/link/summary/15-1152.00
# Downloading:  https://www.onetonline.org/link/summary/15-1131.00
# Downloading:  https://www.onetonline.org/link/summary/15-1121.00
# Downloading:  https://www.onetonline.org/link/summary/15-1121.01
# Downloading:  https://www.onetonline.org/link/summary/15-1151.00
# Downloading:  https://www.onetonline.org/link/summary/15-1141.00
# Downloading:  https://www.onetonline.org/link/summary/15-1122.00
# Downloading:  https://www.onetonline.org/link/summary/15-2099.00
# Downloading:  https://www.onetonline.org/link/summary/15-2091.00
# Downloading:  https://www.onetonline.org/link/summary/15-2021.00
# Downloading:  https://www.onetonline.org/link/summary/15-1142.00
# Downloading:  https://www.onetonline.org/link/summary/15-2031.00
# Downloading:  https://www.onetonline.org/link/summary/15-1132.00
# Downloading:  https://www.onetonline.org/link/summary/15-1133.00
# Downloading:  https://www.onetonline.org/link/summary/15-1134.00
# Downloading:  https://www.onetonline.org/link/summary/47-2011.00
# Downloading:  https://www.onetonline.org/link/summary/47-2021.00
# Downloading:  https://www.onetonline.org/link/summary/47-2031.00
# Downloading:  https://www.onetonline.org/link/summary/47-2031.01
# Downloading:  https://www.onetonline.org/link/summary/47-2031.02
# Downloading:  https://www.onetonline.org/link/summary/47-2041.00
# Downloading:  https://www.onetonline.org/link/summary/47-2051.00
# Downloading:  https://www.onetonline.org/link/summary/47-4011.00
# Downloading:  https://www.onetonline.org/link/summary/47-4099.00
# Downloading:  https://www.onetonline.org/link/summary/47-4099.02
# Downloading:  https://www.onetonline.org/link/summary/47-4099.03
# Downloading:  https://www.onetonline.org/link/summary/47-2061.00
# Downloading:  https://www.onetonline.org/link/summary/47-5041.00
# Downloading:  https://www.onetonline.org/link/summary/47-5011.00
# Downloading:  https://www.onetonline.org/link/summary/47-2081.00
# Downloading:  https://www.onetonline.org/link/summary/47-5021.00
# Downloading:  https://www.onetonline.org/link/summary/47-2111.00
# Downloading:  https://www.onetonline.org/link/summary/47-4021.00
# Downloading:  https://www.onetonline.org/link/summary/47-5031.00
# Downloading:  https://www.onetonline.org/link/summary/47-5099.00
# Downloading:  https://www.onetonline.org/link/summary/47-4031.00
# Downloading:  https://www.onetonline.org/link/summary/47-1011.00
# Downloading:  https://www.onetonline.org/link/summary/47-1011.03
# Downloading:  https://www.onetonline.org/link/summary/47-2042.00
# Downloading:  https://www.onetonline.org/link/summary/47-2043.00
# Downloading:  https://www.onetonline.org/link/summary/47-2121.00
# Downloading:  https://www.onetonline.org/link/summary/47-4041.00
# Downloading:  https://www.onetonline.org/link/summary/47-3019.00
# Downloading:  https://www.onetonline.org/link/summary/47-3011.00
# Downloading:  https://www.onetonline.org/link/summary/47-3012.00
# Downloading:  https://www.onetonline.org/link/summary/47-3013.00
# Downloading:  https://www.onetonline.org/link/summary/47-5081.00
# Downloading:  https://www.onetonline.org/link/summary/47-3014.00
# Downloading:  https://www.onetonline.org/link/summary/47-3015.00
# Downloading:  https://www.onetonline.org/link/summary/47-3016.00
# Downloading:  https://www.onetonline.org/link/summary/47-4051.00
# Downloading:  https://www.onetonline.org/link/summary/47-2131.00
# Downloading:  https://www.onetonline.org/link/summary/47-2132.00
# Downloading:  https://www.onetonline.org/link/summary/47-5042.00
# Downloading:  https://www.onetonline.org/link/summary/47-5049.00
# Downloading:  https://www.onetonline.org/link/summary/47-2073.00
# Downloading:  https://www.onetonline.org/link/summary/47-2141.00
# Downloading:  https://www.onetonline.org/link/summary/47-2142.00
# Downloading:  https://www.onetonline.org/link/summary/47-2071.00
# Downloading:  https://www.onetonline.org/link/summary/47-2072.00
# Downloading:  https://www.onetonline.org/link/summary/47-2152.01
# Downloading:  https://www.onetonline.org/link/summary/47-2152.02
# Downloading:  https://www.onetonline.org/link/summary/47-2152.00
# Downloading:  https://www.onetonline.org/link/summary/47-2151.00
# Downloading:  https://www.onetonline.org/link/summary/47-2161.00
# Downloading:  https://www.onetonline.org/link/summary/47-4061.00
# Downloading:  https://www.onetonline.org/link/summary/47-2171.00
# Downloading:  https://www.onetonline.org/link/summary/47-5051.00
# Downloading:  https://www.onetonline.org/link/summary/47-5061.00
# Downloading:  https://www.onetonline.org/link/summary/47-2181.00
# Downloading:  https://www.onetonline.org/link/summary/47-5012.00
# Downloading:  https://www.onetonline.org/link/summary/47-5071.00
# Downloading:  https://www.onetonline.org/link/summary/47-4091.00
# Downloading:  https://www.onetonline.org/link/summary/47-4071.00
# Downloading:  https://www.onetonline.org/link/summary/47-5013.00
# Downloading:  https://www.onetonline.org/link/summary/47-2211.00
# Downloading:  https://www.onetonline.org/link/summary/47-2231.00
# Downloading:  https://www.onetonline.org/link/summary/47-2022.00
# Downloading:  https://www.onetonline.org/link/summary/47-2221.00
# Downloading:  https://www.onetonline.org/link/summary/47-2082.00
# Downloading:  https://www.onetonline.org/link/summary/47-2053.00
# Downloading:  https://www.onetonline.org/link/summary/47-2044.00
# Downloading:  https://www.onetonline.org/link/summary/25-2059.01
# Downloading:  https://www.onetonline.org/link/summary/25-2059.00
# Downloading:  https://www.onetonline.org/link/summary/25-3011.00
# Downloading:  https://www.onetonline.org/link/summary/25-1041.00
# Downloading:  https://www.onetonline.org/link/summary/25-1061.00
# Downloading:  https://www.onetonline.org/link/summary/25-1031.00
# Downloading:  https://www.onetonline.org/link/summary/25-4011.00
# Downloading:  https://www.onetonline.org/link/summary/25-1062.00
# Downloading:  https://www.onetonline.org/link/summary/25-1121.00
# Downloading:  https://www.onetonline.org/link/summary/25-1051.00
# Downloading:  https://www.onetonline.org/link/summary/25-9011.00
# Downloading:  https://www.onetonline.org/link/summary/25-1042.00
# Downloading:  https://www.onetonline.org/link/summary/25-1011.00
# Downloading:  https://www.onetonline.org/link/summary/25-2023.00
# Downloading:  https://www.onetonline.org/link/summary/25-2032.00
# Downloading:  https://www.onetonline.org/link/summary/25-1052.00
# Downloading:  https://www.onetonline.org/link/summary/25-1122.00
# Downloading:  https://www.onetonline.org/link/summary/25-1021.00
# Downloading:  https://www.onetonline.org/link/summary/25-1111.00
# Downloading:  https://www.onetonline.org/link/summary/25-4012.00
# Downloading:  https://www.onetonline.org/link/summary/25-1063.00
# Downloading:  https://www.onetonline.org/link/summary/25-1081.00
# Downloading:  https://www.onetonline.org/link/summary/25-9099.00
# Downloading:  https://www.onetonline.org/link/summary/25-2021.00
# Downloading:  https://www.onetonline.org/link/summary/25-1032.00
# Downloading:  https://www.onetonline.org/link/summary/25-1123.00
# Downloading:  https://www.onetonline.org/link/summary/25-1053.00
# Downloading:  https://www.onetonline.org/link/summary/25-9021.00
# Downloading:  https://www.onetonline.org/link/summary/25-1124.00
# Downloading:  https://www.onetonline.org/link/summary/25-1043.00
# Downloading:  https://www.onetonline.org/link/summary/25-1064.00
# Downloading:  https://www.onetonline.org/link/summary/25-1191.00
# Downloading:  https://www.onetonline.org/link/summary/25-1071.00
# Downloading:  https://www.onetonline.org/link/summary/25-1125.00
# Downloading:  https://www.onetonline.org/link/summary/25-1192.00
# Downloading:  https://www.onetonline.org/link/summary/25-9031.00
# Downloading:  https://www.onetonline.org/link/summary/25-9031.01
# Downloading:  https://www.onetonline.org/link/summary/25-2012.00
# Downloading:  https://www.onetonline.org/link/summary/25-1112.00
# Downloading:  https://www.onetonline.org/link/summary/25-4021.00
# Downloading:  https://www.onetonline.org/link/summary/25-1082.00
# Downloading:  https://www.onetonline.org/link/summary/25-4031.00
# Downloading:  https://www.onetonline.org/link/summary/25-1022.00
# Downloading:  https://www.onetonline.org/link/summary/25-2022.00
# Downloading:  https://www.onetonline.org/link/summary/25-4013.00
# Downloading:  https://www.onetonline.org/link/summary/25-1072.00
# Downloading:  https://www.onetonline.org/link/summary/25-1126.00
# Downloading:  https://www.onetonline.org/link/summary/25-1054.00
# Downloading:  https://www.onetonline.org/link/summary/25-1065.00
# Downloading:  https://www.onetonline.org/link/summary/25-1199.00
# Downloading:  https://www.onetonline.org/link/summary/25-2011.00
# Downloading:  https://www.onetonline.org/link/summary/25-1066.00
# Downloading:  https://www.onetonline.org/link/summary/25-1193.00
# Downloading:  https://www.onetonline.org/link/summary/25-2031.00
# Downloading:  https://www.onetonline.org/link/summary/25-3021.00
# Downloading:  https://www.onetonline.org/link/summary/25-1069.00
# Downloading:  https://www.onetonline.org/link/summary/25-1113.00
# Downloading:  https://www.onetonline.org/link/summary/25-1067.00
# Downloading:  https://www.onetonline.org/link/summary/25-2052.00
# Downloading:  https://www.onetonline.org/link/summary/25-2053.00
# Downloading:  https://www.onetonline.org/link/summary/25-2051.00
# Downloading:  https://www.onetonline.org/link/summary/25-2054.00
# Downloading:  https://www.onetonline.org/link/summary/25-9041.00
# Downloading:  https://www.onetonline.org/link/summary/25-1194.00
# Downloading:  https://www.onetonline.org/link/summary/45-2091.00
# Downloading:  https://www.onetonline.org/link/summary/45-2011.00
# Downloading:  https://www.onetonline.org/link/summary/45-2099.00
# Downloading:  https://www.onetonline.org/link/summary/45-2021.00
# Downloading:  https://www.onetonline.org/link/summary/45-4021.00
# Downloading:  https://www.onetonline.org/link/summary/45-2092.02
# Downloading:  https://www.onetonline.org/link/summary/45-2092.00
# Downloading:  https://www.onetonline.org/link/summary/45-2092.01
# Downloading:  https://www.onetonline.org/link/summary/45-2093.00
# Downloading:  https://www.onetonline.org/link/summary/45-1011.07
# Downloading:  https://www.onetonline.org/link/summary/45-1011.08
# Downloading:  https://www.onetonline.org/link/summary/45-1011.06
# Downloading:  https://www.onetonline.org/link/summary/45-1011.00
# Downloading:  https://www.onetonline.org/link/summary/45-1011.05
# Downloading:  https://www.onetonline.org/link/summary/45-3011.00
# Downloading:  https://www.onetonline.org/link/summary/45-4011.00
# Downloading:  https://www.onetonline.org/link/summary/45-2041.00
# Downloading:  https://www.onetonline.org/link/summary/45-3021.00
# Downloading:  https://www.onetonline.org/link/summary/45-4023.00
# Downloading:  https://www.onetonline.org/link/summary/45-4022.00
# Downloading:  https://www.onetonline.org/link/summary/45-4029.00
# Downloading:  https://www.onetonline.org/link/summary/35-3022.01
# Downloading:  https://www.onetonline.org/link/summary/35-3022.00
# Downloading:  https://www.onetonline.org/link/summary/35-3011.00
# Downloading:  https://www.onetonline.org/link/summary/35-1011.00
# Downloading:  https://www.onetonline.org/link/summary/35-3021.00
# Downloading:  https://www.onetonline.org/link/summary/35-2019.00
# Downloading:  https://www.onetonline.org/link/summary/35-2011.00
# Downloading:  https://www.onetonline.org/link/summary/35-2012.00
# Downloading:  https://www.onetonline.org/link/summary/35-2013.00
# Downloading:  https://www.onetonline.org/link/summary/35-2014.00
# Downloading:  https://www.onetonline.org/link/summary/35-2015.00
# Downloading:  https://www.onetonline.org/link/summary/35-9011.00
# Downloading:  https://www.onetonline.org/link/summary/35-9021.00
# Downloading:  https://www.onetonline.org/link/summary/35-1012.00
# Downloading:  https://www.onetonline.org/link/summary/35-9099.00
# Downloading:  https://www.onetonline.org/link/summary/35-2021.00
# Downloading:  https://www.onetonline.org/link/summary/35-3041.00
# Downloading:  https://www.onetonline.org/link/summary/35-9031.00
# Downloading:  https://www.onetonline.org/link/summary/35-3031.00
# Downloading:  https://www.onetonline.org/link/summary/29-1199.01
# Downloading:  https://www.onetonline.org/link/summary/29-1199.00
# Downloading:  https://www.onetonline.org/link/summary/29-1199.04
# Downloading:  https://www.onetonline.org/link/summary/29-1199.05
# Downloading:  https://www.onetonline.org/link/summary/29-1141.01
# Downloading:  https://www.onetonline.org/link/summary/29-1141.02
# Downloading:  https://www.onetonline.org/link/summary/29-1141.04
# Downloading:  https://www.onetonline.org/link/summary/29-1141.03
# Downloading:  https://www.onetonline.org/link/summary/29-1141.00
# Downloading:  https://www.onetonline.org/link/summary/29-1069.01
# Downloading:  https://www.onetonline.org/link/summary/29-1069.02
# Downloading:  https://www.onetonline.org/link/summary/29-1069.03
# Downloading:  https://www.onetonline.org/link/summary/29-1069.04
# Downloading:  https://www.onetonline.org/link/summary/29-1069.05
# Downloading:  https://www.onetonline.org/link/summary/29-1069.06
# Downloading:  https://www.onetonline.org/link/summary/29-1069.07
# Downloading:  https://www.onetonline.org/link/summary/29-1069.08
# Downloading:  https://www.onetonline.org/link/summary/29-1069.00
# Downloading:  https://www.onetonline.org/link/summary/29-1069.09
# Downloading:  https://www.onetonline.org/link/summary/29-1069.10
# Downloading:  https://www.onetonline.org/link/summary/29-1069.11
# Downloading:  https://www.onetonline.org/link/summary/29-1069.12
# Downloading:  https://www.onetonline.org/link/summary/29-1071.01
# Downloading:  https://www.onetonline.org/link/summary/29-1071.00
# Downloading:  https://www.onetonline.org/link/summary/29-1061.00
# Downloading:  https://www.onetonline.org/link/summary/29-1125.01
# Downloading:  https://www.onetonline.org/link/summary/29-1125.02
# Downloading:  https://www.onetonline.org/link/summary/29-1125.00
# Downloading:  https://www.onetonline.org/link/summary/29-9091.00
# Downloading:  https://www.onetonline.org/link/summary/29-1181.00
# Downloading:  https://www.onetonline.org/link/summary/29-2031.00
# Downloading:  https://www.onetonline.org/link/summary/29-1011.00
# Downloading:  https://www.onetonline.org/link/summary/29-2011.01
# Downloading:  https://www.onetonline.org/link/summary/29-2011.02
# Downloading:  https://www.onetonline.org/link/summary/29-2011.03
# Downloading:  https://www.onetonline.org/link/summary/29-2011.00
# Downloading:  https://www.onetonline.org/link/summary/29-2021.00
# Downloading:  https://www.onetonline.org/link/summary/29-1029.00
# Downloading:  https://www.onetonline.org/link/summary/29-1021.00
# Downloading:  https://www.onetonline.org/link/summary/29-2032.00
# Downloading:  https://www.onetonline.org/link/summary/29-2051.00
# Downloading:  https://www.onetonline.org/link/summary/29-1031.00
# Downloading:  https://www.onetonline.org/link/summary/29-2041.00
# Downloading:  https://www.onetonline.org/link/summary/29-1128.00
# Downloading:  https://www.onetonline.org/link/summary/29-1062.00
# Downloading:  https://www.onetonline.org/link/summary/29-9092.00
# Downloading:  https://www.onetonline.org/link/summary/29-2099.00
# Downloading:  https://www.onetonline.org/link/summary/29-2099.01
# Downloading:  https://www.onetonline.org/link/summary/29-2099.05
# Downloading:  https://www.onetonline.org/link/summary/29-2099.06
# Downloading:  https://www.onetonline.org/link/summary/29-2099.07
# Downloading:  https://www.onetonline.org/link/summary/29-9099.00
# Downloading:  https://www.onetonline.org/link/summary/29-9099.01
# Downloading:  https://www.onetonline.org/link/summary/29-2092.00
# Downloading:  https://www.onetonline.org/link/summary/29-1063.00
# Downloading:  https://www.onetonline.org/link/summary/29-2061.00
# Downloading:  https://www.onetonline.org/link/summary/29-1122.01
# Downloading:  https://www.onetonline.org/link/summary/29-1122.00
# Downloading:  https://www.onetonline.org/link/summary/29-2035.00
# Downloading:  https://www.onetonline.org/link/summary/29-2012.00
# Downloading:  https://www.onetonline.org/link/summary/29-2071.00
# Downloading:  https://www.onetonline.org/link/summary/29-2033.00
# Downloading:  https://www.onetonline.org/link/summary/29-1151.00
# Downloading:  https://www.onetonline.org/link/summary/29-1161.00
# Downloading:  https://www.onetonline.org/link/summary/29-1171.00
# Downloading:  https://www.onetonline.org/link/summary/29-1064.00
# Downloading:  https://www.onetonline.org/link/summary/29-9011.00
# Downloading:  https://www.onetonline.org/link/summary/29-9012.00
# Downloading:  https://www.onetonline.org/link/summary/29-2057.00
# Downloading:  https://www.onetonline.org/link/summary/29-2081.00
# Downloading:  https://www.onetonline.org/link/summary/29-1041.00
# Downloading:  https://www.onetonline.org/link/summary/29-1022.00
# Downloading:  https://www.onetonline.org/link/summary/29-1023.00
# Downloading:  https://www.onetonline.org/link/summary/29-2091.00
# Downloading:  https://www.onetonline.org/link/summary/29-1065.00
# Downloading:  https://www.onetonline.org/link/summary/29-1051.00
# Downloading:  https://www.onetonline.org/link/summary/29-2052.00
# Downloading:  https://www.onetonline.org/link/summary/29-1123.00
# Downloading:  https://www.onetonline.org/link/summary/29-1081.00
# Downloading:  https://www.onetonline.org/link/summary/29-1024.00
# Downloading:  https://www.onetonline.org/link/summary/29-2053.00
# Downloading:  https://www.onetonline.org/link/summary/29-1066.00
# Downloading:  https://www.onetonline.org/link/summary/29-1124.00
# Downloading:  https://www.onetonline.org/link/summary/29-2034.00
# Downloading:  https://www.onetonline.org/link/summary/29-1126.00
# Downloading:  https://www.onetonline.org/link/summary/29-2054.00
# Downloading:  https://www.onetonline.org/link/summary/29-1127.00
# Downloading:  https://www.onetonline.org/link/summary/29-1067.00
# Downloading:  https://www.onetonline.org/link/summary/29-2055.00
# Downloading:  https://www.onetonline.org/link/summary/29-1129.00
# Downloading:  https://www.onetonline.org/link/summary/29-1131.00
# Downloading:  https://www.onetonline.org/link/summary/29-2056.00
# Downloading:  https://www.onetonline.org/link/summary/31-9091.00
# Downloading:  https://www.onetonline.org/link/summary/31-9099.02
# Downloading:  https://www.onetonline.org/link/summary/31-9099.00
# Downloading:  https://www.onetonline.org/link/summary/31-9099.01
# Downloading:  https://www.onetonline.org/link/summary/31-1011.00
# Downloading:  https://www.onetonline.org/link/summary/31-9011.00
# Downloading:  https://www.onetonline.org/link/summary/31-9092.00
# Downloading:  https://www.onetonline.org/link/summary/31-9093.00
# Downloading:  https://www.onetonline.org/link/summary/31-9094.00
# Downloading:  https://www.onetonline.org/link/summary/31-1014.00
# Downloading:  https://www.onetonline.org/link/summary/31-2012.00
# Downloading:  https://www.onetonline.org/link/summary/31-2011.00
# Downloading:  https://www.onetonline.org/link/summary/31-1015.00
# Downloading:  https://www.onetonline.org/link/summary/31-9095.00
# Downloading:  https://www.onetonline.org/link/summary/31-9097.00
# Downloading:  https://www.onetonline.org/link/summary/31-2022.00
# Downloading:  https://www.onetonline.org/link/summary/31-2021.00
# Downloading:  https://www.onetonline.org/link/summary/31-1013.00
# Downloading:  https://www.onetonline.org/link/summary/31-9096.00
# Downloading:  https://www.onetonline.org/link/summary/49-3011.00
# Downloading:  https://www.onetonline.org/link/summary/49-3021.00
# Downloading:  https://www.onetonline.org/link/summary/49-3022.00
# Downloading:  https://www.onetonline.org/link/summary/49-3023.01
# Downloading:  https://www.onetonline.org/link/summary/49-3023.00
# Downloading:  https://www.onetonline.org/link/summary/49-3023.02
# Downloading:  https://www.onetonline.org/link/summary/49-2091.00
# Downloading:  https://www.onetonline.org/link/summary/49-3091.00
# Downloading:  https://www.onetonline.org/link/summary/49-3031.00
# Downloading:  https://www.onetonline.org/link/summary/49-9061.00
# Downloading:  https://www.onetonline.org/link/summary/49-9091.00
# Downloading:  https://www.onetonline.org/link/summary/49-9092.00
# Downloading:  https://www.onetonline.org/link/summary/49-2011.00
# Downloading:  https://www.onetonline.org/link/summary/49-9012.00
# Downloading:  https://www.onetonline.org/link/summary/49-2092.00
# Downloading:  https://www.onetonline.org/link/summary/49-2093.00
# Downloading:  https://www.onetonline.org/link/summary/49-2094.00
# Downloading:  https://www.onetonline.org/link/summary/49-2095.00
# Downloading:  https://www.onetonline.org/link/summary/49-9051.00
# Downloading:  https://www.onetonline.org/link/summary/49-2096.00
# Downloading:  https://www.onetonline.org/link/summary/49-2097.00
# Downloading:  https://www.onetonline.org/link/summary/49-9093.00
# Downloading:  https://www.onetonline.org/link/summary/49-3041.00
# Downloading:  https://www.onetonline.org/link/summary/49-1011.00
# Downloading:  https://www.onetonline.org/link/summary/49-9099.01
# Downloading:  https://www.onetonline.org/link/summary/49-9099.00
# Downloading:  https://www.onetonline.org/link/summary/49-9021.01
# Downloading:  https://www.onetonline.org/link/summary/49-9021.00
# Downloading:  https://www.onetonline.org/link/summary/49-9021.02
# Downloading:  https://www.onetonline.org/link/summary/49-9098.00
# Downloading:  https://www.onetonline.org/link/summary/49-9031.00
# Downloading:  https://www.onetonline.org/link/summary/49-9041.00
# Downloading:  https://www.onetonline.org/link/summary/49-9094.00
# Downloading:  https://www.onetonline.org/link/summary/49-9071.00
# Downloading:  https://www.onetonline.org/link/summary/49-9043.00
# Downloading:  https://www.onetonline.org/link/summary/49-9095.00
# Downloading:  https://www.onetonline.org/link/summary/49-9011.00
# Downloading:  https://www.onetonline.org/link/summary/49-9062.00
# Downloading:  https://www.onetonline.org/link/summary/49-9044.00
# Downloading:  https://www.onetonline.org/link/summary/49-3042.00
# Downloading:  https://www.onetonline.org/link/summary/49-3051.00
# Downloading:  https://www.onetonline.org/link/summary/49-3052.00
# Downloading:  https://www.onetonline.org/link/summary/49-9063.00
# Downloading:  https://www.onetonline.org/link/summary/49-3053.00
# Downloading:  https://www.onetonline.org/link/summary/49-9069.00
# Downloading:  https://www.onetonline.org/link/summary/49-2021.01
# Downloading:  https://www.onetonline.org/link/summary/49-2021.00
# Downloading:  https://www.onetonline.org/link/summary/49-3043.00
# Downloading:  https://www.onetonline.org/link/summary/49-3092.00
# Downloading:  https://www.onetonline.org/link/summary/49-9045.00
# Downloading:  https://www.onetonline.org/link/summary/49-9096.00
# Downloading:  https://www.onetonline.org/link/summary/49-2098.00
# Downloading:  https://www.onetonline.org/link/summary/49-9097.00
# Downloading:  https://www.onetonline.org/link/summary/49-2022.00
# Downloading:  https://www.onetonline.org/link/summary/49-9052.00
# Downloading:  https://www.onetonline.org/link/summary/49-3093.00
# Downloading:  https://www.onetonline.org/link/summary/49-9064.00
# Downloading:  https://www.onetonline.org/link/summary/49-9081.00
# Downloading:  https://www.onetonline.org/link/summary/23-1021.00
# Downloading:  https://www.onetonline.org/link/summary/23-1022.00
# Downloading:  https://www.onetonline.org/link/summary/23-2091.00
# Downloading:  https://www.onetonline.org/link/summary/23-1023.00
# Downloading:  https://www.onetonline.org/link/summary/23-1012.00
# Downloading:  https://www.onetonline.org/link/summary/23-1011.00
# Downloading:  https://www.onetonline.org/link/summary/23-2099.00
# Downloading:  https://www.onetonline.org/link/summary/23-2011.00
# Downloading:  https://www.onetonline.org/link/summary/23-2093.00
# Downloading:  https://www.onetonline.org/link/summary/19-4011.00
# Downloading:  https://www.onetonline.org/link/summary/19-4011.01
# Downloading:  https://www.onetonline.org/link/summary/19-4011.02
# Downloading:  https://www.onetonline.org/link/summary/19-1011.00
# Downloading:  https://www.onetonline.org/link/summary/19-3091.01
# Downloading:  https://www.onetonline.org/link/summary/19-3091.00
# Downloading:  https://www.onetonline.org/link/summary/19-3091.02
# Downloading:  https://www.onetonline.org/link/summary/19-2011.00
# Downloading:  https://www.onetonline.org/link/summary/19-2021.00
# Downloading:  https://www.onetonline.org/link/summary/19-1021.00
# Downloading:  https://www.onetonline.org/link/summary/19-1029.01
# Downloading:  https://www.onetonline.org/link/summary/19-1029.00
# Downloading:  https://www.onetonline.org/link/summary/19-1029.03
# Downloading:  https://www.onetonline.org/link/summary/19-1029.02
# Downloading:  https://www.onetonline.org/link/summary/19-4021.00
# Downloading:  https://www.onetonline.org/link/summary/19-4031.00
# Downloading:  https://www.onetonline.org/link/summary/19-2031.00
# Downloading:  https://www.onetonline.org/link/summary/19-4061.01
# Downloading:  https://www.onetonline.org/link/summary/19-4061.00
# Downloading:  https://www.onetonline.org/link/summary/19-2041.01
# Downloading:  https://www.onetonline.org/link/summary/19-2041.02
# Downloading:  https://www.onetonline.org/link/summary/19-2041.00
# Downloading:  https://www.onetonline.org/link/summary/19-2041.03
# Downloading:  https://www.onetonline.org/link/summary/19-3031.02
# Downloading:  https://www.onetonline.org/link/summary/19-3031.00
# Downloading:  https://www.onetonline.org/link/summary/19-3031.03
# Downloading:  https://www.onetonline.org/link/summary/19-3031.01
# Downloading:  https://www.onetonline.org/link/summary/19-1031.00
# Downloading:  https://www.onetonline.org/link/summary/19-1031.03
# Downloading:  https://www.onetonline.org/link/summary/19-1031.02
# Downloading:  https://www.onetonline.org/link/summary/19-1031.01
# Downloading:  https://www.onetonline.org/link/summary/19-3011.00
# Downloading:  https://www.onetonline.org/link/summary/19-3011.01
# Downloading:  https://www.onetonline.org/link/summary/19-4091.00
# Downloading:  https://www.onetonline.org/link/summary/19-1041.00
# Downloading:  https://www.onetonline.org/link/summary/19-1012.00
# Downloading:  https://www.onetonline.org/link/summary/19-4092.00
# Downloading:  https://www.onetonline.org/link/summary/19-4093.00
# Downloading:  https://www.onetonline.org/link/summary/19-1032.00
# Downloading:  https://www.onetonline.org/link/summary/19-3092.00
# Downloading:  https://www.onetonline.org/link/summary/19-4041.00
# Downloading:  https://www.onetonline.org/link/summary/19-4041.02
# Downloading:  https://www.onetonline.org/link/summary/19-4041.01
# Downloading:  https://www.onetonline.org/link/summary/19-2042.00
# Downloading:  https://www.onetonline.org/link/summary/19-3093.00
# Downloading:  https://www.onetonline.org/link/summary/19-2043.00
# Downloading:  https://www.onetonline.org/link/summary/19-3032.00
# Downloading:  https://www.onetonline.org/link/summary/19-1099.00
# Downloading:  https://www.onetonline.org/link/summary/19-4099.00
# Downloading:  https://www.onetonline.org/link/summary/19-4099.02
# Downloading:  https://www.onetonline.org/link/summary/19-4099.01
# Downloading:  https://www.onetonline.org/link/summary/19-4099.03
# Downloading:  https://www.onetonline.org/link/summary/19-2032.00
# Downloading:  https://www.onetonline.org/link/summary/19-1042.00
# Downloading:  https://www.onetonline.org/link/summary/19-1022.00
# Downloading:  https://www.onetonline.org/link/summary/19-3039.01
# Downloading:  https://www.onetonline.org/link/summary/19-3039.00
# Downloading:  https://www.onetonline.org/link/summary/19-4051.01
# Downloading:  https://www.onetonline.org/link/summary/19-4051.02
# Downloading:  https://www.onetonline.org/link/summary/19-4051.00
# Downloading:  https://www.onetonline.org/link/summary/19-2099.00
# Downloading:  https://www.onetonline.org/link/summary/19-2099.01
# Downloading:  https://www.onetonline.org/link/summary/19-2012.00
# Downloading:  https://www.onetonline.org/link/summary/19-3094.00
# Downloading:  https://www.onetonline.org/link/summary/19-3099.00
# Downloading:  https://www.onetonline.org/link/summary/19-3099.01
# Downloading:  https://www.onetonline.org/link/summary/19-3041.00
# Downloading:  https://www.onetonline.org/link/summary/19-1013.00
# Downloading:  https://www.onetonline.org/link/summary/19-3022.00
# Downloading:  https://www.onetonline.org/link/summary/19-3051.00
# Downloading:  https://www.onetonline.org/link/summary/19-1023.00
# Downloading:  https://www.onetonline.org/link/summary/11-3011.00
# Downloading:  https://www.onetonline.org/link/summary/11-2011.00
# Downloading:  https://www.onetonline.org/link/summary/11-2011.01
# Downloading:  https://www.onetonline.org/link/summary/11-9013.03
# Downloading:  https://www.onetonline.org/link/summary/11-9013.02
# Downloading:  https://www.onetonline.org/link/summary/11-9013.00
# Downloading:  https://www.onetonline.org/link/summary/11-9013.01
# Downloading:  https://www.onetonline.org/link/summary/11-9041.00
# Downloading:  https://www.onetonline.org/link/summary/11-9041.01
# Downloading:  https://www.onetonline.org/link/summary/11-3051.03
# Downloading:  https://www.onetonline.org/link/summary/11-3051.04
# Downloading:  https://www.onetonline.org/link/summary/11-3051.02
# Downloading:  https://www.onetonline.org/link/summary/11-3051.06
# Downloading:  https://www.onetonline.org/link/summary/11-3051.00
# Downloading:  https://www.onetonline.org/link/summary/11-3051.05
# Downloading:  https://www.onetonline.org/link/summary/11-3051.01
# Downloading:  https://www.onetonline.org/link/summary/11-9199.11
# Downloading:  https://www.onetonline.org/link/summary/11-9199.02
# Downloading:  https://www.onetonline.org/link/summary/11-9199.03
# Downloading:  https://www.onetonline.org/link/summary/11-9199.08
# Downloading:  https://www.onetonline.org/link/summary/11-9199.00
# Downloading:  https://www.onetonline.org/link/summary/11-9199.01
# Downloading:  https://www.onetonline.org/link/summary/11-9199.07
# Downloading:  https://www.onetonline.org/link/summary/11-9199.04
# Downloading:  https://www.onetonline.org/link/summary/11-9199.09
# Downloading:  https://www.onetonline.org/link/summary/11-9199.10
# Downloading:  https://www.onetonline.org/link/summary/11-1011.00
# Downloading:  https://www.onetonline.org/link/summary/11-1011.03
# Downloading:  https://www.onetonline.org/link/summary/11-9121.01
# Downloading:  https://www.onetonline.org/link/summary/11-9121.00
# Downloading:  https://www.onetonline.org/link/summary/11-9121.02
# Downloading:  https://www.onetonline.org/link/summary/11-3111.00
# Downloading:  https://www.onetonline.org/link/summary/11-3021.00
# Downloading:  https://www.onetonline.org/link/summary/11-9021.00
# Downloading:  https://www.onetonline.org/link/summary/11-9039.01
# Downloading:  https://www.onetonline.org/link/summary/11-9039.00
# Downloading:  https://www.onetonline.org/link/summary/11-9039.02
# Downloading:  https://www.onetonline.org/link/summary/11-9032.00
# Downloading:  https://www.onetonline.org/link/summary/11-9033.00
# Downloading:  https://www.onetonline.org/link/summary/11-9031.00
# Downloading:  https://www.onetonline.org/link/summary/11-9161.00
# Downloading:  https://www.onetonline.org/link/summary/11-3031.00
# Downloading:  https://www.onetonline.org/link/summary/11-3031.02
# Downloading:  https://www.onetonline.org/link/summary/11-3031.01
# Downloading:  https://www.onetonline.org/link/summary/11-9051.00
# Downloading:  https://www.onetonline.org/link/summary/11-9061.00
# Downloading:  https://www.onetonline.org/link/summary/11-9071.00
# Downloading:  https://www.onetonline.org/link/summary/11-1021.00
# Downloading:  https://www.onetonline.org/link/summary/11-3121.00
# Downloading:  https://www.onetonline.org/link/summary/11-1031.00
# Downloading:  https://www.onetonline.org/link/summary/11-9081.00
# Downloading:  https://www.onetonline.org/link/summary/11-3071.03
# Downloading:  https://www.onetonline.org/link/summary/11-3071.02
# Downloading:  https://www.onetonline.org/link/summary/11-3071.01
# Downloading:  https://www.onetonline.org/link/summary/11-3071.00
# Downloading:  https://www.onetonline.org/link/summary/11-2021.00
# Downloading:  https://www.onetonline.org/link/summary/11-9111.00
# Downloading:  https://www.onetonline.org/link/summary/11-9131.00
# Downloading:  https://www.onetonline.org/link/summary/11-9141.00
# Downloading:  https://www.onetonline.org/link/summary/11-2031.00
# Downloading:  https://www.onetonline.org/link/summary/11-3061.00
# Downloading:  https://www.onetonline.org/link/summary/11-2022.00
# Downloading:  https://www.onetonline.org/link/summary/11-9151.00
# Downloading:  https://www.onetonline.org/link/summary/11-3131.00
# Downloading:  https://www.onetonline.org/link/summary/43-3011.00
# Downloading:  https://www.onetonline.org/link/summary/43-3021.00
# ...
# Downloading:  https://www.onetonline.org/link/summary/39-7012.00
# Downloading:  https://www.onetonline.org/link/summary/39-3031.00
# Downloading:  https://www.onetonline.org/link/summary/51-9191.00
# Downloading:  https://www.onetonline.org/link/summary/51-2011.00
# Downloading:  https://www.onetonline.org/link/summary/51-2099.00
# Downloading:  https://www.onetonline.org/link/summary/51-3011.00
# Downloading:  https://www.onetonline.org/link/summary/51-8099.01
# Downloading:  https://www.onetonline.org/link/summary/51-8099.03
# Downloading:  https://www.onetonline.org/link/summary/51-8099.04
# Downloading:  https://www.onetonline.org/link/summary/51-8099.02
# Downloading:  https://www.onetonline.org/link/summary/51-8099.00
# Downloading:  https://www.onetonline.org/link/summary/51-3021.00
# Downloading:  https://www.onetonline.org/link/summary/51-7011.00
# Downloading:  https://www.onetonline.org/link/summary/51-9011.00
# Downloading:  https://www.onetonline.org/link/summary/51-8091.00
# Downloading:  https://www.onetonline.org/link/summary/51-9192.00
# Downloading:  https://www.onetonline.org/link/summary/51-9121.00
# Downloading:  https://www.onetonline.org/link/summary/51-2021.00
# Downloading:  https://www.onetonline.org/link/summary/51-4012.00
# Downloading:  https://www.onetonline.org/link/summary/51-4011.00
# Downloading:  https://www.onetonline.org/link/summary/51-9193.00
# Downloading:  https://www.onetonline.org/link/summary/51-9021.00
# Downloading:  https://www.onetonline.org/link/summary/51-9031.00
# Downloading:  https://www.onetonline.org/link/summary/51-9032.00
# Downloading:  https://www.onetonline.org/link/summary/51-4031.00
# Downloading:  https://www.onetonline.org/link/summary/51-9081.00
# Downloading:  https://www.onetonline.org/link/summary/51-4032.00
# Downloading:  https://www.onetonline.org/link/summary/51-2022.00
# Downloading:  https://www.onetonline.org/link/summary/51-2023.00
# Downloading:  https://www.onetonline.org/link/summary/51-2031.00
# Downloading:  https://www.onetonline.org/link/summary/51-9194.00
# Downloading:  https://www.onetonline.org/link/summary/51-4021.00
# Downloading:  https://www.onetonline.org/link/summary/51-6091.00
# Downloading:  https://www.onetonline.org/link/summary/51-9041.00
# Downloading:  https://www.onetonline.org/link/summary/51-6092.00
# Downloading:  https://www.onetonline.org/link/summary/51-2091.00
# Downloading:  https://www.onetonline.org/link/summary/51-1011.00
# Downloading:  https://www.onetonline.org/link/summary/51-3091.00
# Downloading:  https://www.onetonline.org/link/summary/51-3092.00
# Downloading:  https://www.onetonline.org/link/summary/51-3093.00
# Downloading:  https://www.onetonline.org/link/summary/51-3099.00
# Downloading:  https://www.onetonline.org/link/summary/51-4022.00
# Downloading:  https://www.onetonline.org/link/summary/51-4071.00
# Downloading:  https://www.onetonline.org/link/summary/51-9051.00
# Downloading:  https://www.onetonline.org/link/summary/51-7021.00
# Downloading:  https://www.onetonline.org/link/summary/51-8092.00
# Downloading:  https://www.onetonline.org/link/summary/51-9071.06
# Downloading:  https://www.onetonline.org/link/summary/51-9071.01
# Downloading:  https://www.onetonline.org/link/summary/51-9071.00
# Downloading:  https://www.onetonline.org/link/summary/51-9071.07
# Downloading:  https://www.onetonline.org/link/summary/51-9195.04
# Downloading:  https://www.onetonline.org/link/summary/51-9195.00
# Downloading:  https://www.onetonline.org/link/summary/51-9195.07
# Downloading:  https://www.onetonline.org/link/summary/51-9195.05
# Downloading:  https://www.onetonline.org/link/summary/51-9195.03
# Downloading:  https://www.onetonline.org/link/summary/51-9022.00
# Downloading:  https://www.onetonline.org/link/summary/51-4033.00
# Downloading:  https://www.onetonline.org/link/summary/51-4191.00
# Downloading:  https://www.onetonline.org/link/summary/51-9198.00
# Downloading:  https://www.onetonline.org/link/summary/51-9061.00
# Downloading:  https://www.onetonline.org/link/summary/51-4034.00
# Downloading:  https://www.onetonline.org/link/summary/51-6011.00
# Downloading:  https://www.onetonline.org/link/summary/51-4192.00
# Downloading:  https://www.onetonline.org/link/summary/51-4041.00
# Downloading:  https://www.onetonline.org/link/summary/51-3022.00
# Downloading:  https://www.onetonline.org/link/summary/51-9082.00
# Downloading:  https://www.onetonline.org/link/summary/51-4199.00
# Downloading:  https://www.onetonline.org/link/summary/51-4051.00
# Downloading:  https://www.onetonline.org/link/summary/51-4035.00
# Downloading:  https://www.onetonline.org/link/summary/51-9023.00
# Downloading:  https://www.onetonline.org/link/summary/51-4061.00
# Downloading:  https://www.onetonline.org/link/summary/51-7031.00
# Downloading:  https://www.onetonline.org/link/summary/51-4072.00
# Downloading:  https://www.onetonline.org/link/summary/51-4081.00
# Downloading:  https://www.onetonline.org/link/summary/51-8011.00
# Downloading:  https://www.onetonline.org/link/summary/51-9083.00
# Downloading:  https://www.onetonline.org/link/summary/51-9111.00
# Downloading:  https://www.onetonline.org/link/summary/51-9122.00
# Downloading:  https://www.onetonline.org/link/summary/51-9123.00
# Downloading:  https://www.onetonline.org/link/summary/51-9196.00
# Downloading:  https://www.onetonline.org/link/summary/51-4062.00
# Downloading:  https://www.onetonline.org/link/summary/51-7032.00
# Downloading:  https://www.onetonline.org/link/summary/51-8093.00
# Downloading:  https://www.onetonline.org/link/summary/51-9151.00
# Downloading:  https://www.onetonline.org/link/summary/51-4193.00
# Downloading:  https://www.onetonline.org/link/summary/51-4052.00
# Downloading:  https://www.onetonline.org/link/summary/51-8012.00
# Downloading:  https://www.onetonline.org/link/summary/51-8013.00
# Downloading:  https://www.onetonline.org/link/summary/51-5111.00
# Downloading:  https://www.onetonline.org/link/summary/51-6021.00
# Downloading:  https://www.onetonline.org/link/summary/51-5113.00
# Downloading:  https://www.onetonline.org/link/summary/51-5112.00
# Downloading:  https://www.onetonline.org/link/summary/51-9199.00
# Downloading:  https://www.onetonline.org/link/summary/51-9199.01
# Downloading:  https://www.onetonline.org/link/summary/51-4023.00
# Downloading:  https://www.onetonline.org/link/summary/51-7041.00
# Downloading:  https://www.onetonline.org/link/summary/51-9141.00
# Downloading:  https://www.onetonline.org/link/summary/51-9012.00
# Downloading:  https://www.onetonline.org/link/summary/51-6051.00
# Downloading:  https://www.onetonline.org/link/summary/51-6031.00
# Downloading:  https://www.onetonline.org/link/summary/51-6041.00
# Downloading:  https://www.onetonline.org/link/summary/51-6042.00
# Downloading:  https://www.onetonline.org/link/summary/51-3023.00
# Downloading:  https://www.onetonline.org/link/summary/51-4121.07
# Downloading:  https://www.onetonline.org/link/summary/51-4121.06
# Downloading:  https://www.onetonline.org/link/summary/51-4121.00
# Downloading:  https://www.onetonline.org/link/summary/51-8021.00
# Downloading:  https://www.onetonline.org/link/summary/51-2041.00
# Downloading:  https://www.onetonline.org/link/summary/51-6052.00
# Downloading:  https://www.onetonline.org/link/summary/51-2092.00
# Downloading:  https://www.onetonline.org/link/summary/51-6061.00
# Downloading:  https://www.onetonline.org/link/summary/51-6062.00
# Downloading:  https://www.onetonline.org/link/summary/51-6063.00
# Downloading:  https://www.onetonline.org/link/summary/51-6064.00
# Downloading:  https://www.onetonline.org/link/summary/51-6099.00
# Downloading:  https://www.onetonline.org/link/summary/51-2093.00
# Downloading:  https://www.onetonline.org/link/summary/51-9197.00
# Downloading:  https://www.onetonline.org/link/summary/51-4111.00
# Downloading:  https://www.onetonline.org/link/summary/51-4194.00
# Downloading:  https://www.onetonline.org/link/summary/51-6093.00
# Downloading:  https://www.onetonline.org/link/summary/51-8031.00
# Downloading:  https://www.onetonline.org/link/summary/51-4122.00
# Downloading:  https://www.onetonline.org/link/summary/51-7099.00
# Downloading:  https://www.onetonline.org/link/summary/51-7042.00
# Downloading:  https://www.onetonline.org/link/summary/33-9011.00
# Downloading:  https://www.onetonline.org/link/summary/33-3011.00
# Downloading:  https://www.onetonline.org/link/summary/33-3012.00
# Downloading:  https://www.onetonline.org/link/summary/33-3021.03
# Downloading:  https://www.onetonline.org/link/summary/33-3021.00
# Downloading:  https://www.onetonline.org/link/summary/33-3021.05
# Downloading:  https://www.onetonline.org/link/summary/33-3021.06
# Downloading:  https://www.onetonline.org/link/summary/33-3021.01
# Downloading:  https://www.onetonline.org/link/summary/33-3021.02
# Downloading:  https://www.onetonline.org/link/summary/33-9091.00
# Downloading:  https://www.onetonline.org/link/summary/33-2021.01
# Downloading:  https://www.onetonline.org/link/summary/33-2021.00
# Downloading:  https://www.onetonline.org/link/summary/33-2021.02
# Downloading:  https://www.onetonline.org/link/summary/33-2011.00
# Downloading:  https://www.onetonline.org/link/summary/33-2011.02
# Downloading:  https://www.onetonline.org/link/summary/33-2011.01
# Downloading:  https://www.onetonline.org/link/summary/33-1011.00
# Downloading:  https://www.onetonline.org/link/summary/33-1021.00
# Downloading:  https://www.onetonline.org/link/summary/33-1021.02
# Downloading:  https://www.onetonline.org/link/summary/33-1021.01
# Downloading:  https://www.onetonline.org/link/summary/33-1012.00
# Downloading:  https://www.onetonline.org/link/summary/33-1099.00
# Downloading:  https://www.onetonline.org/link/summary/33-3031.00
# Downloading:  https://www.onetonline.org/link/summary/33-2022.00
# Downloading:  https://www.onetonline.org/link/summary/33-9031.00
# Downloading:  https://www.onetonline.org/link/summary/33-9092.00
# Downloading:  https://www.onetonline.org/link/summary/33-3041.00
# Downloading:  https://www.onetonline.org/link/summary/33-3051.00
# Downloading:  https://www.onetonline.org/link/summary/33-3051.01
# Downloading:  https://www.onetonline.org/link/summary/33-3051.03
# Downloading:  https://www.onetonline.org/link/summary/33-9021.00
# Downloading:  https://www.onetonline.org/link/summary/33-9099.00
# Downloading:  https://www.onetonline.org/link/summary/33-9099.02
# Downloading:  https://www.onetonline.org/link/summary/33-9032.00
# Downloading:  https://www.onetonline.org/link/summary/33-3052.00
# Downloading:  https://www.onetonline.org/link/summary/33-9093.00
# Downloading:  https://www.onetonline.org/link/summary/41-3011.00
# Downloading:  https://www.onetonline.org/link/summary/41-2011.00
# Downloading:  https://www.onetonline.org/link/summary/41-2021.00
# Downloading:  https://www.onetonline.org/link/summary/41-9011.00
# Downloading:  https://www.onetonline.org/link/summary/41-9091.00
# Downloading:  https://www.onetonline.org/link/summary/41-3099.01
# Downloading:  https://www.onetonline.org/link/summary/41-3099.00
# Downloading:  https://www.onetonline.org/link/summary/41-1012.00
# Downloading:  https://www.onetonline.org/link/summary/41-1011.00
# Downloading:  https://www.onetonline.org/link/summary/41-2012.00
# Downloading:  https://www.onetonline.org/link/summary/41-3021.00
# Downloading:  https://www.onetonline.org/link/summary/41-9012.00
# Downloading:  https://www.onetonline.org/link/summary/41-2022.00
# Downloading:  https://www.onetonline.org/link/summary/41-9021.00
# Downloading:  https://www.onetonline.org/link/summary/41-9022.00
# Downloading:  https://www.onetonline.org/link/summary/41-2031.00
# Downloading:  https://www.onetonline.org/link/summary/41-3031.02
# Downloading:  https://www.onetonline.org/link/summary/41-3031.01
# Downloading:  https://www.onetonline.org/link/summary/41-3031.03
# Downloading:  https://www.onetonline.org/link/summary/41-3031.00
# Downloading:  https://www.onetonline.org/link/summary/41-9099.00
# Downloading:  https://www.onetonline.org/link/summary/41-9031.00
# Downloading:  https://www.onetonline.org/link/summary/41-4012.00
# Downloading:  https://www.onetonline.org/link/summary/41-4011.00
# Downloading:  https://www.onetonline.org/link/summary/41-4011.07
# Downloading:  https://www.onetonline.org/link/summary/41-9041.00
# Downloading:  https://www.onetonline.org/link/summary/41-3041.00
# Downloading:  https://www.onetonline.org/link/summary/53-2021.00
# Downloading:  https://www.onetonline.org/link/summary/53-1011.00
# Downloading:  https://www.onetonline.org/link/summary/53-2022.00
# Downloading:  https://www.onetonline.org/link/summary/53-2011.00
# Downloading:  https://www.onetonline.org/link/summary/53-3011.00
# Downloading:  https://www.onetonline.org/link/summary/53-6031.00
# Downloading:  https://www.onetonline.org/link/summary/53-6051.01
# Downloading:  https://www.onetonline.org/link/summary/53-6051.08
# Downloading:  https://www.onetonline.org/link/summary/53-6051.00
# Downloading:  https://www.onetonline.org/link/summary/53-6051.07
# Downloading:  https://www.onetonline.org/link/summary/53-6011.00
# Downloading:  https://www.onetonline.org/link/summary/53-3022.00
# Downloading:  https://www.onetonline.org/link/summary/53-3021.00
# Downloading:  https://www.onetonline.org/link/summary/53-5021.00
# Downloading:  https://www.onetonline.org/link/summary/53-5021.02
# Downloading:  https://www.onetonline.org/link/summary/53-5021.03
# Downloading:  https://www.onetonline.org/link/summary/53-5021.01
# Downloading:  https://www.onetonline.org/link/summary/53-7061.00
# Downloading:  https://www.onetonline.org/link/summary/53-2012.00
# Downloading:  https://www.onetonline.org/link/summary/53-7011.00
# Downloading:  https://www.onetonline.org/link/summary/53-7021.00
# Downloading:  https://www.onetonline.org/link/summary/53-7031.00
# Downloading:  https://www.onetonline.org/link/summary/53-3031.00
# Downloading:  https://www.onetonline.org/link/summary/53-7032.00
# Downloading:  https://www.onetonline.org/link/summary/53-1021.00
# Downloading:  https://www.onetonline.org/link/summary/53-1021.01
# Downloading:  https://www.onetonline.org/link/summary/53-1031.00
# Downloading:  https://www.onetonline.org/link/summary/53-2031.00
# Downloading:  https://www.onetonline.org/link/summary/53-7071.00
# Downloading:  https://www.onetonline.org/link/summary/53-3032.00
# Downloading:  https://www.onetonline.org/link/summary/53-7041.00
# Downloading:  https://www.onetonline.org/link/summary/53-7051.00
# Downloading:  https://www.onetonline.org/link/summary/53-7062.00
# Downloading:  https://www.onetonline.org/link/summary/53-3033.00
# Downloading:  https://www.onetonline.org/link/summary/53-7033.00
# Downloading:  https://www.onetonline.org/link/summary/53-4011.00
# Downloading:  https://www.onetonline.org/link/summary/53-4012.00
# Downloading:  https://www.onetonline.org/link/summary/53-7063.00
# Downloading:  https://www.onetonline.org/link/summary/53-7199.00
# Downloading:  https://www.onetonline.org/link/summary/53-7111.00
# Downloading:  https://www.onetonline.org/link/summary/53-3099.00
# Downloading:  https://www.onetonline.org/link/summary/53-5022.00
# Downloading:  https://www.onetonline.org/link/summary/53-7064.00
# Downloading:  https://www.onetonline.org/link/summary/53-6021.00
# Downloading:  https://www.onetonline.org/link/summary/53-7072.00
# Downloading:  https://www.onetonline.org/link/summary/53-4099.00
# Downloading:  https://www.onetonline.org/link/summary/53-4013.00
# Downloading:  https://www.onetonline.org/link/summary/53-4021.00
# Downloading:  https://www.onetonline.org/link/summary/53-4031.00
# Downloading:  https://www.onetonline.org/link/summary/53-7081.00
# Downloading:  https://www.onetonline.org/link/summary/53-5011.00
# Downloading:  https://www.onetonline.org/link/summary/53-5031.00
# Downloading:  https://www.onetonline.org/link/summary/53-4041.00
# Downloading:  https://www.onetonline.org/link/summary/53-7121.00
# Downloading:  https://www.onetonline.org/link/summary/53-3041.00
# Downloading:  https://www.onetonline.org/link/summary/53-6041.00
# Downloading:  https://www.onetonline.org/link/summary/53-6061.00
# Downloading:  https://www.onetonline.org/link/summary/53-6099.00
# Downloading:  https://www.onetonline.org/link/summary/53-7073.00

# %%
onetReports.to_csv("onetReports.txt", sep="\t")

# %%
def roleRep(col):
    summaries = []
    for i in col:
        soup = BeautifulSoup(i)
        summaries.append(soup.find("p").get_text())
    return summaries

# %%
onet['summary'] = roleRep(onetReports)
# Out:
# /usr/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /usr/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html5lib")
#
#   markup_type=markup_type))

# %%
def roleSampls(col):
    sampls = []
    for i in col:
        soup = BeautifulSoup(i)
        sample_Titles = soup.find("p").next_sibling.get_text()
        for i,char in enumerate(sample_Titles):
            if char == ":":
                pos = i+2
                break
        sampls.append(sample_Titles[pos:-1])
    return sampls

# %%
onet['sampleTitles'] = roleSampls(onetReports)
# Out:
# /usr/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /usr/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html5lib")
#
#   markup_type=markup_type))

# %%
onet.head()
# Out:
#       Code                                      Occupation_x  \
# 0  17-3021  Aerospace Engineering and Operations Technicians
# 1  17-2011                               Aerospace Engineers
# 2  17-2021                            Agricultural Engineers
# 3  17-1011          Architects, Except Landscape and Naval
# 4  17-3011                  Architectural and Civil Drafters
#
#                      Job Family  \
# 0  Architecture and Engineering
# 1  Architecture and Engineering
# 2  Architecture and Engineering
# 3  Architecture and Engineering
# 4  Architecture and Engineering
#
#                                    Career Cluster  \
# 0                                   Manufacturing
# 1  Science, Technology, Engineering & Mathematics
# 2           Agriculture, Food & Natural Resources
# 3                     Architecture & Construction
# 4                     Architecture & Construction
#
#                                  Career Pathway  \
# 0  Manufacturing Production Process Development
# 1                    Engineering and Technology
# 2         Power, Structural & Technical Systems
# 3                       Design/Pre-Construction
# 4                       Design/Pre-Construction
#
#                                        Occupation_y    fullCode SCode  \
# 0  Aerospace Engineering and Operations Technicians  17-3021.00   .00
# 1                               Aerospace Engineers  17-2011.00   .00
# 2                            Agricultural Engineers  17-2021.00   .00
# 3            Architects, Except Landscape and Naval  17-1011.00   .00
# 4                  Architectural and Civil Drafters  17-3011.00   .00
#
#                                          word_tokens  \
# 0  [Aerospace, Engineering, and, Operations, Tech...
# 1                             [Aerospace, Engineers]
# 2                          [Agricultural, Engineers]
# 3        [Architects, Except, Landscape, and, Naval]
# 4              [Architectural, and, Civil, Drafters]
#
#                                               Title  \
# 0  Aerospace Engineering and Operations Technicians
# 1                               Aerospace Engineers
# 2                            Agricultural Engineers
# 3            Architects, Except Landscape and Naval
# 4                  Architectural and Civil Drafters
#
#                                              summary  \
# 0  Operate, install, calibrate, and maintain inte...
# 1  Perform engineering duties in designing, const...
# 2  Apply knowledge of engineering technology and ...
# 3  Plan and design structures, such as private re...
# 4  Prepare detailed drawings of architectural and...
#
#                                         sampleTitles  \
# 0  Avionics Technician, Avionics Test Technician,...
# 1  Aeronautical Engineer, Aerospace Engineer, Aer...
# 2  Agricultural Engineer, Agricultural Safety and...
# 3  Architect; Architectural Project Manager; Desi...
# 4  f more specific occupations. For additional in...
#
#                                       summary_tokens  \
# 0  [Operate, install, calibrate, and, maintain, i...
# 1  [Perform, engineering, duties, in, designing, ...
# 2  [Apply, knowledge, of, engineering, technology...
# 3  [Plan, and, design, structures, such, as, priv...
# 4  [Prepare, detailed, drawings, of, architectura...
#
#                                       sampleT_tokens
# 0  [Avionics, Technician, Avionics, Test, Technic...
# 1  [Aeronautical, Engineer, Aerospace, Engineer, ...
# 2  [Agricultural, Engineer, Agricultural, Safety,...
# 3  [Architect, Architectural, Project, Manager, D...
# 4  [f, more, specific, occupations, For, addition...

# %%
#testing out onet pages parser vvv
#html = D("https://www.onetonline.org/link/summary/13-2011.01")

# %%
'''
#print(html['html'])
soup = BeautifulSoup(html['html'])

Summary = soup.find("p").get_text()
sample_Titles = soup.find("p").next_sibling.get_text()
for i,char in enumerate(sample_Titles):
    if char == ":":
        pos = i+2
        break
sample_Titles = sample_Titles[pos:]
print(sample_Titles)
#sample_Titles = [sib for sib in soup.find("p").next_siblings]
#print(sample_Titles[0])
'''
# Out:
# '\n#print(html[\'html\'])\nsoup = BeautifulSoup(html[\'html\'])\n\nSummary = soup.find("p").get_text()\nsample_Titles = soup.find("p").next_sibling.get_text()\nfor i,char in enumerate(sample_Titles):\n    if char == ":":\n        pos = i+2\n        break\nsample_Titles = sample_Titles[pos:]\nprint(sample_Titles)\n#sample_Titles = [sib for sib in soup.find("p").next_siblings]\n#print(sample_Titles[0])\n'

# %%
titles = onet.filter(['Occupation_x', 'Occupation_y', 'summary', 'sampleTitles'], axis=1)
#titles = pd.merge(titles, pd.DataFrame(onetM.Occupation_y), right_index=True, left_index=True)
titles
titles.to_csv("Titles.txt", sep="\t")

# %%
onet['summary_tokens'] = onet.summary.apply(tokenizer.tokenize)
onet['sampleT_tokens'] = onet.sampleTitles.apply(tokenizer.tokenize)

# %%
onet.head()
# Out:
#       Code                                      Occupation_x  \
# 0  17-3021  Aerospace Engineering and Operations Technicians
# 1  17-2011                               Aerospace Engineers
# 2  17-2021                            Agricultural Engineers
# 3  17-1011          Architects, Except Landscape and Naval
# 4  17-3011                  Architectural and Civil Drafters
#
#                      Job Family  \
# 0  Architecture and Engineering
# 1  Architecture and Engineering
# 2  Architecture and Engineering
# 3  Architecture and Engineering
# 4  Architecture and Engineering
#
#                                    Career Cluster  \
# 0                                   Manufacturing
# 1  Science, Technology, Engineering & Mathematics
# 2           Agriculture, Food & Natural Resources
# 3                     Architecture & Construction
# 4                     Architecture & Construction
#
#                                  Career Pathway  \
# 0  Manufacturing Production Process Development
# 1                    Engineering and Technology
# 2         Power, Structural & Technical Systems
# 3                       Design/Pre-Construction
# 4                       Design/Pre-Construction
#
#                                        Occupation_y    fullCode SCode  \
# 0  Aerospace Engineering and Operations Technicians  17-3021.00   .00
# 1                               Aerospace Engineers  17-2011.00   .00
# 2                            Agricultural Engineers  17-2021.00   .00
# 3            Architects, Except Landscape and Naval  17-1011.00   .00
# 4                  Architectural and Civil Drafters  17-3011.00   .00
#
#                                          word_tokens  \
# 0  [Aerospace, Engineering, and, Operations, Tech...
# 1                             [Aerospace, Engineers]
# 2                          [Agricultural, Engineers]
# 3        [Architects, Except, Landscape, and, Naval]
# 4              [Architectural, and, Civil, Drafters]
#
#                                               Title  \
# 0  Aerospace Engineering and Operations Technicians
# 1                               Aerospace Engineers
# 2                            Agricultural Engineers
# 3            Architects, Except Landscape and Naval
# 4                  Architectural and Civil Drafters
#
#                                              summary  \
# 0  Operate, install, calibrate, and maintain inte...
# 1  Perform engineering duties in designing, const...
# 2  Apply knowledge of engineering technology and ...
# 3  Plan and design structures, such as private re...
# 4  Prepare detailed drawings of architectural and...
#
#                                         sampleTitles  \
# 0  Avionics Technician, Avionics Test Technician,...
# 1  Aeronautical Engineer, Aerospace Engineer, Aer...
# 2  Agricultural Engineer, Agricultural Safety and...
# 3  Architect; Architectural Project Manager; Desi...
# 4  f more specific occupations. For additional in...
#
#                                       summary_tokens  \
# 0  [Operate, install, calibrate, and, maintain, i...
# 1  [Perform, engineering, duties, in, designing, ...
# 2  [Apply, knowledge, of, engineering, technology...
# 3  [Plan, and, design, structures, such, as, priv...
# 4  [Prepare, detailed, drawings, of, architectura...
#
#                                       sampleT_tokens
# 0  [Avionics, Technician, Avionics, Test, Technic...
# 1  [Aeronautical, Engineer, Aerospace, Engineer, ...
# 2  [Agricultural, Engineer, Agricultural, Safety,...
# 3  [Architect, Architectural, Project, Manager, D...
# 4  [f, more, specific, occupations, For, addition...

# %%
#onet.to_csv("combined_onet.txt", sep="\t")

# %%
import numpy as np 
import pandas as pd
from nltk.corpus import wordnet

# %%
onet = pd.read_csv("data/combined_onet.txt", sep="\t")

# %% [markdown]
# ### tokenization must be redone because those vals are read in as strings not converted to lists vvvv

# %%
from nltk.tokenize import RegexpTokenizer

# %%
tokenizer = RegexpTokenizer("[\w']+")
def WT(ls):
    col = []
    for i in ls:
        col.append(tokenizer.tokenize(i))
    return col

# %%
onet['word_tokens'] = onet.Occupation_y.apply(tokenizer.tokenize)

# %%
onet['summary_tokens'] = onet.summary.apply(tokenizer.tokenize)

# %%
onet['sampleT_tokens'] = onet.sampleTitles.apply(tokenizer.tokenize)

# %%
onet.tail()
# Out:
#       Unnamed: 0     Code                                       Occupation_x  \
# 1082        1082  53-3041                        Taxi Drivers and Chauffeurs
# 1083        1083  53-6041                                Traffic Technicians
# 1084        1084  53-6061  Transportation Attendants, Except Flight Atten...
# 1085        1085  53-6099                  Transportation Workers, All Other
# 1086        1086  53-7073                                   Wellhead Pumpers
#
#                               Job Family  \
# 1082  Transportation and Material Moving
# 1083  Transportation and Material Moving
# 1084  Transportation and Material Moving
# 1085  Transportation and Material Moving
# 1086  Transportation and Material Moving
#
#                                 Career Cluster  \
# 1082  Transportation, Distribution & Logistics
# 1083  Transportation, Distribution & Logistics
# 1084  Transportation, Distribution & Logistics
# 1085  Transportation, Distribution & Logistics
# 1086  Transportation, Distribution & Logistics
#
#                                          Career Pathway  \
# 1082                          Transportation Operations
# 1083  Transportation Systems/Infrastructure Planning...
# 1084                          Transportation Operations
# 1085                          Transportation Operations
# 1086                          Transportation Operations
#
#                                            Occupation_y    fullCode  SCode  \
# 1082                        Taxi Drivers and Chauffeurs  53-3041.00    0.0
# 1083                                Traffic Technicians  53-6041.00    0.0
# 1084  Transportation Attendants, Except Flight Atten...  53-6061.00    0.0
# 1085                  Transportation Workers, All Other  53-6099.00    0.0
# 1086                                   Wellhead Pumpers  53-7073.00    0.0
#
#                                             word_tokens  \
# 1082                   [Taxi, Drivers, and, Chauffeurs]
# 1083                             [Traffic, Technicians]
# 1084  [Transportation, Attendants, Except, Flight, A...
# 1085              [Transportation, Workers, All, Other]
# 1086                                [Wellhead, Pumpers]
#
#                                                   Title  \
# 1082                        Taxi Drivers and Chauffeurs
# 1083                                Traffic Technicians
# 1084  Transportation Attendants, Except Flight Atten...
# 1085                  Transportation Workers, All Other
# 1086                                   Wellhead Pumpers
#
#                                                 summary  \
# 1082  Drive automobiles, vans, or limousines to tran...
# 1083  Conduct field studies to determine traffic vol...
# 1084  Provide services to ensure the safety and comf...
# 1085  All transportation workers not listed separately.
# 1086  Operate power pumps and auxiliary equipment to...
#
#                                            sampleTitles  \
# 1082  Cab Driver, Chauffeur, Driver, Limousine Drive...
# 1083  Engineering Technician, Field Traffic Investig...
# 1084  Bus Aide, Bus Assistant, Bus Attendant, Bus Mo...
# 1085  cupations with a wide range of characteristics...
# 1086  Gauger, Lease Operator, Multi-Skilled Operator...
#
#                                          summary_tokens  \
# 1082  [Drive, automobiles, vans, or, limousines, to,...
# 1083  [Conduct, field, studies, to, determine, traff...
# 1084  [Provide, services, to, ensure, the, safety, a...
# 1085  [All, transportation, workers, not, listed, se...
# 1086  [Operate, power, pumps, and, auxiliary, equipm...
#
#                                          sampleT_tokens
# 1082  [Cab, Driver, Chauffeur, Driver, Limousine, Dr...
# 1083  [Engineering, Technician, Field, Traffic, Inve...
# 1084  [Bus, Aide, Bus, Assistant, Bus, Attendant, Bu...
# 1085  [cupations, with, a, wide, range, of, characte...
# 1086  [Gauger, Lease, Operator, Multi, Skilled, Oper...

# %% [markdown]
# ### Make some ngrams using Onet data

# %%
from nltk.corpus import webtext
from nltk.collocations import BigramCollocationFinder
from nltk.collocations import TrigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
from nltk.metrics import TrigramAssocMeasures
words = [w.lower() for w in webtext.words('Titles.txt')]
bcf = BigramCollocationFinder.from_words(words)
tcf = TrigramCollocationFinder.from_words(words)

# %%
bcf.nbest(BigramAssocMeasures.likelihood_ratio,4)
# Out:
# [('such', 'as'), ('.', 'may'), ('all', 'other'), ('operator', ',')]

# %%
tcf.nbest(TrigramAssocMeasures.likelihood_ratio,4)
# Out:
# [(',', 'such', 'as'),
#  ('areas', 'such', 'as'),
#  ('duties', 'such', 'as'),
#  ('such', 'as', 'a')]

# %%
from nltk.corpus import stopwords
stopset = set(stopwords.words('english'))
filter_stops = lambda w: len(w) < 3 or w in stopset
bcf.apply_word_filter(filter_stops)
tcf.apply_word_filter(filter_stops)

# %%
bcf.nbest(BigramAssocMeasures.likelihood_ratio, 4)
# Out:
# [('listed', 'separately'),
#  ('real', 'estate'),
#  ('vice', 'president'),
#  ('line', 'supervisors')]

# %%
tcf.nbest(TrigramAssocMeasures.likelihood_ratio, 4)
# Out:
# [('postsecondary', 'teach', 'courses'),
#  ('teachers', 'primarily', 'engaged'),
#  ('geographic', 'information', 'systems'),
#  ('special', 'education', 'teacher')]

# %%
bcf.score_ngrams(BigramAssocMeasures.likelihood_ratio)[:5]
# Out:
# [(('listed', 'separately'), 1125.9969615711857),
#  (('real', 'estate'), 577.3966406928769),
#  (('vice', 'president'), 575.2095108203183),
#  (('line', 'supervisors'), 536.9621261999703),
#  (('machine', 'operator'), 498.56179999894584)]

# %%
tcf.score_ngrams(TrigramAssocMeasures.likelihood_ratio)[:5]
# Out:
# [(('postsecondary', 'teach', 'courses'), 1394.4536380112377),
#  (('teachers', 'primarily', 'engaged'), 1366.999889309856),
#  (('geographic', 'information', 'systems'), 1012.2440198719406),
#  (('special', 'education', 'teacher'), 991.5522421408288),
#  (('real', 'estate', 'appraiser'), 983.427370804294)]

# %% [markdown]
# ### create synsets for titles

# %%
onet.columns
# Out:
# Index(['Unnamed: 0', 'Code', 'Occupation_x', 'Job Family', 'Career Cluster',
#        'Career Pathway', 'Occupation_y', 'fullCode', 'SCode', 'word_tokens',
#        'Title', 'summary', 'sampleTitles', 'summary_tokens', 'sampleT_tokens'],
#       dtype='object')

# %% [markdown]
# ## Role Text to title Matching

# %%
import nltk
from nltk.tokenize import sent_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/iss/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('webtext')
# Out:
# [nltk_data] Downloading package stopwords to /home/iss/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/iss/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package webtext to /home/iss/nltk_data...
# [nltk_data]   Unzipping corpora/webtext.zip.
# True

# %%
from nltk.corpus import stopwords
english_stops = set(stopwords.words('english'))

# %%
onet['word_tokens_stopw'] = onet.word_tokens.apply(lambda x: [word for word in x if word not in english_stops])

# %%
onet['summary_tokens_stopw'] = onet.summary_tokens.apply(lambda x: [word for word in x if word not in english_stops])
onet['sample_tokens_stopw'] = onet.sampleT_tokens.apply(lambda x: [word for word in x if word not in english_stops])

# %%
def synMaker(ls):
    syns = []
    for i in ls:
        syns.append(wordnet.synsets(i))
    return syns

# %%
wordnet.synsets('operate')
# Out:
# [Synset('operate.v.01'),
#  Synset('function.v.01'),
#  Synset('operate.v.03'),
#  Synset('manoeuver.v.03'),
#  Synset('operate.v.05'),
#  Synset('engage.v.10'),
#  Synset('operate_on.v.01')]

# %%
#loops through words for job titles and retrieves all synsets for each
onet['syns'] = onet.word_tokens_stopw.apply(synMaker)
onet['summary_syns'] = onet.summary_tokens_stopw.apply(synMaker)
onet['sample_syns'] = onet.sample_tokens_stopw.apply(synMaker)

# %%
onet.syns[0]
# Out:
# [[Synset('aerospace.n.01')],
#  [Synset('technology.n.01'),
#   Synset('engineering.n.02'),
#   Synset('engineering.n.03'),
#   Synset('engineer.v.01'),
#   Synset('mastermind.v.01')],
#  [Synset('operations.n.01'),
#   Synset('operation.n.01'),
#   Synset('operation.n.02'),
#   Synset('operation.n.03'),
#   Synset('operation.n.04'),
#   Synset('operation.n.05'),
#   Synset('operation.n.06'),
#   Synset('operation.n.07'),
#   Synset('operation.n.08'),
#   Synset('process.n.02'),
#   Synset('mathematical_process.n.01'),
#   Synset('operation.n.11')],
#  [Synset('technician.n.01'), Synset('technician.n.02')]]

# %%
def lemming(ls):
    col = []
    for i in ls:
        newList = []
        for j in i:
            newList.append(j.lemmas())
        col.append(newList)
    return col

# %%
onet['lemmings'] = onet.syns.apply(lemming)
onet['summary_lem'] = onet.summary_syns.apply(lemming)
onet['sample_lem'] = onet.sample_syns.apply(lemming)

# %%
#onet.summarylem[4]

# %%
def synonyms(ls):
    col = []
    for i in ls:
        newList = []
        for j in i:
            #loops through the lists of synsets for each word getting lemmas or synonyms then
            #loops again through the lemmas returning just the names or words themselves
            #This looping syntax below is relatively new to me but I believe it loops through the in argument
            #and returns the values requested prior to the 'for' statment
            newList.append([lemma.name() for lemma in j.lemmas()])
        col.append(newList)
    return col

# %%
onet['synonyms'] = onet.syns.apply(synonyms)
onet['summary_synonyms'] = onet.summary_syns.apply(synonyms)
onet['sample_synonyms'] = onet.sample_syns.apply(synonyms)

# %%
#onet.summary_synonyms[4]

# %%
onet.syns[7]
# Out:
# [[Synset('automotive.a.01'), Synset('automotive.s.02')],
#  [Synset('technology.n.01'),
#   Synset('engineering.n.02'),
#   Synset('engineering.n.03'),
#   Synset('engineer.v.01'),
#   Synset('mastermind.v.01')],
#  [Synset('technician.n.01'), Synset('technician.n.02')]]

# %% [markdown]
# ### Combine above functions into one to return a flat list of synonyms (does not seperate synonyms for multiple words)

# %%
### chained synonym getter passing in synsets returning flattened synonym list
def flatSynonym(synList):
    synonyms = []
    for synset in synList:
        for word in synset:
            for lemma in word.lemmas():
                synonyms.append(lemma.name())
    return synonyms

# %%
onet['flatSynonyms'] = onet.syns.apply(flatSynonym)
onet['summary_flatSynonyms'] = onet.summary_syns.apply(flatSynonym)
onet['sample_flatSynonyms'] = onet.sample_syns.apply(flatSynonym)

# %%
onet.summary_flatSynonyms[4][:5]
# Out:
# ['fix', 'prepare', 'set_up', 'ready', 'gear_up']

# %%
onet.iloc[4]
# Out:
# Unnamed: 0                                                              4
# Code                                                              17-3011
# Occupation_x                             Architectural and Civil Drafters
# Job Family                                   Architecture and Engineering
# Career Cluster                                Architecture & Construction
# Career Pathway                                    Design/Pre-Construction
# Occupation_y                             Architectural and Civil Drafters
# fullCode                                                       17-3011.00
# SCode                                                                   0
# word_tokens                         [Architectural, and, Civil, Drafters]
# Title                                    Architectural and Civil Drafters
# summary                 Prepare detailed drawings of architectural and...
# sampleTitles            f more specific occupations. For additional in...
# summary_tokens          [Prepare, detailed, drawings, of, architectura...
# sampleT_tokens          [f, more, specific, occupations, For, addition...
# syns                    [[Synset('architectural.a.01')], [], [Synset('...
# summary_syns            [[Synset('fix.v.12'), Synset('cook.v.02'), Syn...
# sample_syns             [[Synset('degree_fahrenheit.n.01'), Synset('fl...
# lemmings                [[[Lemma('architectural.a.01.architectural')]]...
# summary_lem             [[[Lemma('fix.v.12.fix'), Lemma('fix.v.12.prep...
# sample_lem              [[[Lemma('degree_fahrenheit.n.01.degree_Fahren...
# synonyms                [[[architectural]], [], [[civil], [civil, poli...
# summary_synonyms        [[[fix, prepare, set_up, ready, gear_up, set],...
# sample_synonyms         [[[degree_Fahrenheit, F], [fluorine, F, atomic...
# flatSynonyms            [architectural, civil, civil, polite, civil, c...
# summary_flatSynonyms    [fix, prepare, set_up, ready, gear_up, set, co...
# sample_flatSynonyms     [degree_Fahrenheit, F, fluorine, F, atomic_num...
# Name: 4, dtype: object

# %%
onet.syns[4]
# Out:
# [[Synset('architectural.a.01')],
#  [],
#  [Synset('civil.s.01'),
#   Synset('civil.a.02'),
#   Synset('civil.a.03'),
#   Synset('civil.a.04'),
#   Synset('civil.a.05'),
#   Synset('civil.s.06')],
#  [Synset('drafter.n.01')]]

# %%
### chained synonym getter passing in synsets returning flattened synonym list
def flatLemming(synList):
    synonyms = []
    for synset in synList:
        for word in synset:
            for lemma in word.lemmas():
                syn = wordnet.synsets(lemma.name())
                synonyms.append([ID.name() for ID in syn])
    return synonyms
        
def lems(ls):
    synlems = []
    for word in ls:
        synlems.append(word.lemmas())
    return synlems

# %%
#overkill
onet['flatLemmings'] = onet.syns.apply(flatLemming)
onet.flatLemmings[4][:5]
# Out:
# [['architectural.a.01'],
#  ['civil.s.01',
#   'civil.a.02',
#   'civil.a.03',
#   'civil.a.04',
#   'civil.a.05',
#   'civil.s.06'],
#  ['civil.s.01',
#   'civil.a.02',
#   'civil.a.03',
#   'civil.a.04',
#   'civil.a.05',
#   'civil.s.06'],
#  ['polite.a.01', 'civilized.s.02', 'civil.a.02'],
#  ['civil.s.01',
#   'civil.a.02',
#   'civil.a.03',
#   'civil.a.04',
#   'civil.a.05',
#   'civil.s.06']]

# %%
onet.head()
# Out:
#    Unnamed: 0     Code                                      Occupation_x  \
# 0           0  17-3021  Aerospace Engineering and Operations Technicians
# 1           1  17-2011                               Aerospace Engineers
# 2           2  17-2021                            Agricultural Engineers
# 3           3  17-1011          Architects, Except Landscape and Naval
# 4           4  17-3011                  Architectural and Civil Drafters
#
#                      Job Family  \
# 0  Architecture and Engineering
# 1  Architecture and Engineering
# 2  Architecture and Engineering
# 3  Architecture and Engineering
# 4  Architecture and Engineering
#
#                                    Career Cluster  \
# 0                                   Manufacturing
# 1  Science, Technology, Engineering & Mathematics
# 2           Agriculture, Food & Natural Resources
# 3                     Architecture & Construction
# 4                     Architecture & Construction
#
#                                  Career Pathway  \
# 0  Manufacturing Production Process Development
# 1                    Engineering and Technology
# 2         Power, Structural & Technical Systems
# 3                       Design/Pre-Construction
# 4                       Design/Pre-Construction
#
#                                        Occupation_y    fullCode  SCode  \
# 0  Aerospace Engineering and Operations Technicians  17-3021.00    0.0
# 1                               Aerospace Engineers  17-2011.00    0.0
# 2                            Agricultural Engineers  17-2021.00    0.0
# 3            Architects, Except Landscape and Naval  17-1011.00    0.0
# 4                  Architectural and Civil Drafters  17-3011.00    0.0
#
#                                          word_tokens  \
# 0  [Aerospace, Engineering, and, Operations, Tech...
# 1                             [Aerospace, Engineers]
# 2                          [Agricultural, Engineers]
# 3        [Architects, Except, Landscape, and, Naval]
# 4              [Architectural, and, Civil, Drafters]
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                             synonyms  \
# 0  [[[aerospace]], [[technology, engineering], [e...
# 1  [[[aerospace]], [[engineer, applied_scientist,...
# 2  [[[agricultural], [agrarian, agricultural, far...
# 3  [[[architect, designer]], [[demur, except], [e...
# 4  [[[architectural]], [], [[civil], [civil, poli...
#
#                                     summary_synonyms  \
# 0  [[[operate, run], [function, work, operate, go...
# 1  [[[perform, execute, do], [perform], [perform]...
# 2  [[[use, utilize, utilise, apply, employ], [app...
# 3  [[[plan, program, programme], [design, plan], ...
# 4  [[[fix, prepare, set_up, ready, gear_up, set],...
#
#                                      sample_synonyms  \
# 0  [[[avionics]], [[technician], [technician]], [...
# 1  [[[aeronautical, aeronautic]], [[engineer, app...
# 2  [[[agricultural], [agrarian, agricultural, far...
# 3  [[[architect, designer]], [[architectural]], [...
# 4  [[[degree_Fahrenheit, F], [fluorine, F, atomic...
#
#                                         flatSynonyms  \
# 0  [aerospace, technology, engineering, engineeri...
# 1  [aerospace, engineer, applied_scientist, techn...
# 2  [agricultural, agrarian, agricultural, farming...
# 3  [architect, designer, demur, except, exclude, ...
# 4  [architectural, civil, civil, polite, civil, c...
#
#                                 summary_flatSynonyms  \
# 0  [operate, run, function, work, operate, go, ru...
# 1  [perform, execute, do, perform, perform, do, p...
# 2  [use, utilize, utilise, apply, employ, apply, ...
# 3  [plan, program, programme, design, plan, plan,...
# 4  [fix, prepare, set_up, ready, gear_up, set, co...
#
#                                  sample_flatSynonyms  \
# 0  [avionics, technician, technician, avionics, t...
# 1  [aeronautical, aeronautic, engineer, applied_s...
# 2  [agricultural, agrarian, agricultural, farming...
# 3  [architect, designer, architectural, undertaki...
# 4  [degree_Fahrenheit, F, fluorine, F, atomic_num...
#
#                                         flatLemmings  \
# 0  [[aerospace.n.01], [technology.n.01, engineeri...
# 1  [[aerospace.n.01], [engineer.n.01, engineer.n....
# 2  [[agricultural.a.01, agrarian.s.01], [agrarian...
# 3  [[architect.n.01], [interior_designer.n.01, ar...
# 4  [[architectural.a.01], [civil.s.01, civil.a.02...
#
#                                    word_tokens_stopw  \
# 0  [Aerospace, Engineering, Operations, Technicians]
# 1                             [Aerospace, Engineers]
# 2                          [Agricultural, Engineers]
# 3             [Architects, Except, Landscape, Naval]
# 4                   [Architectural, Civil, Drafters]
#
#                                 summary_tokens_stopw  \
# 0  [Operate, install, calibrate, maintain, integr...
# 1  [Perform, engineering, duties, designing, cons...
# 2  [Apply, knowledge, engineering, technology, bi...
# 3  [Plan, design, structures, private, residences...
# 4  [Prepare, detailed, drawings, architectural, s...
#
#                                  sample_tokens_stopw
# 0  [Avionics, Technician, Avionics, Test, Technic...
# 1  [Aeronautical, Engineer, Aerospace, Engineer, ...
# 2  [Agricultural, Engineer, Agricultural, Safety,...
# 3  [Architect, Architectural, Project, Manager, D...
# 4  [f, specific, occupations, For, additional, in...
#
# [5 rows x 31 columns]

# %%
def matcher(resume):
    list_of_positions_lists_of_scores = []
    for list_of_job_descriptions in resume:
        list_of_positions_lists_of_scores.append(onetJobCycler(list_of_job_descriptions, onet.syns))
        print(len(list_of_positions_lists_of_scores[0]))
            #word_score_list = []
    return list_of_positions_lists_of_scores
            
def onetJobCycler(jobDescription, jobPotentialsList):
    job_scores = []
    for i,job in enumerate(jobPotentialsList):
    #for i,job in enumerate(onet.syns): #all_possible_job_descriptions:
        job_score_tracker = 0
        #print(jobDescription)
        for wordsyn in jobDescription:
            #record Wu-Palmer similarity score to each word in each job category description in Onet data
            job_score_tracker += onetWordCycler(wordsyn, job)
        job_scores.append(job_score_tracker)
    return job_scores
            
#word_score_list.append(word_score_tracker) #save word scores to list for analysis if needed

def onetWordCycler(word, pos):
    word_score = 0
    for w in pos:
        for syns in w:
            #print(syns)
            if syns:
                wup_score = word.wup_similarity(syns)
                #print(wup_score)
                if wup_score:
                    word_score += wup_score
    return word_score

# %%
dfwx['potentialJob_scores'] = dfwx.syns.apply(matcher)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-d0346d1918cc> in <module>()
# ----> 1 dfwx['potentialJob_scores'] = dfwx.syns.apply(matcher)
#
# NameError: name 'dfwx' is not defined
